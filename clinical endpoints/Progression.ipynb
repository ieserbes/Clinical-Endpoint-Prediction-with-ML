# %% [markdown]
# #### Feature selection for Progression

# %%
#Load the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import metrics
from sklearn.preprocessing import LabelEncoder

# %%
#En son veriler
X_train=pd.read_csv("X_train.csv", index_col="ID")
X_test=pd.read_csv("X_test.csv", index_col="ID")
y_train=pd.read_csv("y_train.csv", index_col="ID")
y_test=pd.read_csv("y_test.csv", index_col="ID")

# %%
y_train["Progression"].value_counts()
# Out:
# Progression
# 0    181
# 1    117
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
# #only get one target
y_progression=y_train["Progression"]

# Initialize the LabelEncoder
label_encoder = LabelEncoder()

# Fit and transform the class labels to numeric values
y_progression_encode = label_encoder.fit_transform(y_progression)

# Now, if you want to get the original labels from the encoded values:
original_labels = label_encoder.inverse_transform(y_progression_encode)

# %%
X_train
# Out:
#           Gender_F  Gender_M  clinico.genetic.subgroup_MNA  \
# ID
# ICGC_466       1.0       0.0                           0.0
# ICGC_292       0.0       1.0                           0.0
# ICGC_032       1.0       0.0                           0.0
# ICGC_408       0.0       1.0                           1.0
# ICGC_108       0.0       1.0                           0.0
# ...            ...       ...                           ...
# ICGC_309       0.0       1.0                           0.0
# ICGC_371       1.0       0.0                           0.0
# ICGC_107       1.0       0.0                           0.0
# ICGC_344       0.0       1.0                           0.0
# ICGC_053       0.0       1.0                           0.0
#
#           clinico.genetic.subgroup_ST1  clinico.genetic.subgroup_ST4  \
# ID
# ICGC_466                           0.0                           1.0
# ICGC_292                           0.0                           0.0
# ICGC_032                           1.0                           0.0
# ICGC_408                           0.0                           0.0
# ICGC_108                           0.0                           1.0
# ...                                ...                           ...
# ICGC_309                           0.0                           0.0
# ICGC_371                           0.0                           1.0
# ICGC_107                           1.0                           0.0
# ICGC_344                           1.0                           0.0
# ICGC_053                           1.0                           0.0
#
#           clinico.genetic.subgroup_ST4S  MYCN.status_Amp  MYCN.status_NoAmp  \
# ID
# ICGC_466                            0.0              0.0                1.0
# ICGC_292                            1.0              0.0                1.0
# ICGC_032                            0.0              0.0                1.0
# ICGC_408                            0.0              1.0                0.0
# ICGC_108                            0.0              0.0                1.0
# ...                                 ...              ...                ...
# ICGC_309                            1.0              0.0                1.0
# ICGC_371                            0.0              0.0                1.0
# ICGC_107                            0.0              0.0                1.0
# ICGC_344                            0.0              0.0                1.0
# ICGC_053                            0.0              0.0                1.0
#
#                Age  Unnamed: 14  ...  Unnamed: 44712  Unnamed: 44713  \
# ID                               ...
# ICGC_466  0.480811    -0.488997  ...       -1.653599       -0.106549
# ICGC_292 -0.677666     1.277924  ...       -1.338185        0.067910
# ICGC_032 -0.404137    -0.162796  ...        0.974848        0.067910
# ICGC_408  0.026905     0.471483  ...       -0.873826       -0.869807
# ICGC_108 -0.427002    -0.072185  ...        0.002323        0.820265
# ...            ...          ...  ...             ...             ...
# ICGC_309 -0.738639     0.081854  ...       -0.023962        0.493154
# ICGC_371  0.518919     1.142007  ...       -0.716120       -0.259200
# ICGC_107 -0.379579     0.081854  ...        2.043750        0.067910
# ICGC_344 -0.487127    -0.371202  ...        0.203837        0.743939
# ICGC_053 -0.732711     0.036549  ...       -0.549651        0.067910
#
#              PDE3B  Unnamed: 44715  LINC01588  Unnamed: 44717  Unnamed: 44718  \
# ID
# ICGC_466  0.851564       -1.848442   0.378614       -1.019042        0.089275
# ICGC_292  1.017450       -0.278487  -1.188787       -0.878331        0.330762
# ICGC_032  1.143839        0.615659   0.854896        0.983374        0.049027
# ICGC_408 -0.736202       -0.132929  -0.920337       -1.419525        0.089275
# ICGC_108 -0.728302        0.012630   2.552192        0.777720       -0.796179
# ...            ...             ...        ...             ...             ...
# ICGC_309 -0.270141        0.054218  -0.643228       -0.715973       -0.916923
# ICGC_371  0.180121        0.345336  -0.400757       -0.531968        0.230142
# ICGC_107  0.630382        0.470100   0.664383        1.416328        1.095472
# ICGC_344 -0.104255       -1.058266   3.695269       -0.066541       -0.474196
# ICGC_053 -0.941584       -0.590399   0.248719        0.312294        0.089275
#
#           Unnamed: 44719  Unnamed: 44720  Unnamed: 44721
# ID
# ICGC_466       -0.019078        0.488320        0.427556
# ICGC_292       -0.378721       -0.571040       -0.804698
# ICGC_032        0.900780        0.712416        0.174353
# ICGC_408       -2.349844       -1.915612        0.039312
# ICGC_108        1.633899       -0.204338        0.663879
# ...                  ...             ...             ...
# ICGC_309       -1.167170       -0.530295        0.039312
# ICGC_371       -0.357972       -0.082105        0.393796
# ICGC_107        1.087518        0.916139        0.292515
# ICGC_344        2.290940        0.732788        1.136525
# ICGC_053       -0.385637       -1.059975       -0.045089
#
# [298 rows x 43300 columns]

# %% [markdown]
# #### Random Forest Feature selection

# %%
# # Import necessary libraries
# from sklearn.model_selection import StratifiedKFold, GridSearchCV
# from sklearn.ensemble import RandomForestClassifier
# import matplotlib.pyplot as plt
# import seaborn as sns
# import pandas as pd
# from sklearn.feature_selection import SelectKBest, chi2, f_classif, mutual_info_classif, SelectPercentile
# from sklearn.model_selection import KFold, StratifiedKFold, StratifiedGroupKFold
# from sklearn.metrics import accuracy_score, f1_score

# skf = StratifiedKFold(n_splits=5)

# rf = RandomForestClassifier()

# # Initialize lists to store accuracy and F1 scores for each fold
# accuracy_scores = []
# f1_scores = []

# ## Number of top features
# top_k = 300

# # Initialize list to hold common features from each fold
# common_features = []

# # Iterate over each split
# # Iterate over each split
# for train_index, test_index in skf.split(X, y):
#     X_train_temp, X_test_temp = X.iloc[train_index], X.iloc[test_index]  
#     y_train_temp, y_test_temp = y[train_index], y[test_index]

#     # Initialize feature selectors
#     selector_kbest = SelectKBest(score_func=f_classif, k=top_k)  # Adjust 'k' as per your requirements
#     selector_percentile = SelectPercentile(score_func=f_classif, percentile=1)
    
#     # Fit and transforX_train, y_trainm the data
#     X_new_kbest = selector_kbest.fit_transform(X_train_temp, y_train_temp)
#     X_new_percentile = selector_percentile.fit_transform(X_train_temp, y_train_temp)
    
#     # Get the selected features
#     selected_features_kbest = X_train_temp.columns[selector_kbest.get_support()]
#     selected_features_percentile = X_train_temp.columns[selector_percentile.get_support()]
    
#     # Get the common features and add to the list
#     common_features_fold = set(selected_features_kbest) & set(selected_features_percentile)
#     common_features.append(common_features_fold)
#     #print("Common Features in thi Fold : ", common_features_fold )

#     # Train the model on the selected features and compute the accuracy
#     X_train_selected = X_train_temp[list(common_features_fold)]
#     X_test_selected = X_test_temp[list(common_features_fold)]
#     rf.fit(X_train_selected, y_train_temp)
#     y_pred = rf.predict(X_test_selected)

#      # Calculate accuracy
#     accuracy = accuracy_score(y_test_temp, y_pred)
    
#     # Calculate F1 score
#     f1 = f1_score(y_test_temp, y_pred, average="weighted")

#     print(f'Accuracy for this fold: {accuracy}')
#     print(f'F1 score for this fold: {f1}')

#     # Append scores to the lists
#     accuracy_scores.append(accuracy)
#     f1_scores.append(f1)

# # Calculate the mean accuracy and F1 score
# mean_accuracy = sum(accuracy_scores) / len(accuracy_scores)
# mean_f1_score = sum(f1_scores) / len(f1_scores)

# print(f'Mean Accuracy: {mean_accuracy}')
# print(f'Mean F1 Score: {mean_f1_score}')


# # Get the intersection of common features from all folds
# final_common_features = set.intersection(*map(set, common_features))

# print(f"Final common features: {final_common_features}")
# Out:
# C:\Users\isile\AppData\Local\Temp\ipykernel_14176\4139189586.py:29: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   y_train_temp, y_test_temp = y[train_index], y[test_index]
# Accuracy for this fold: 0.8333333333333334
# F1 score for this fold: 0.8319623971797885
# C:\Users\isile\AppData\Local\Temp\ipykernel_14176\4139189586.py:29: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   y_train_temp, y_test_temp = y[train_index], y[test_index]
# Accuracy for this fold: 0.8
# F1 score for this fold: 0.8011428571428572
# C:\Users\isile\AppData\Local\Temp\ipykernel_14176\4139189586.py:29: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   y_train_temp, y_test_temp = y[train_index], y[test_index]
# Accuracy for this fold: 0.7833333333333333
# F1 score for this fold: 0.7841542796075004
# C:\Users\isile\AppData\Local\Temp\ipykernel_14176\4139189586.py:29: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   y_train_temp, y_test_temp = y[train_index], y[test_index]
# Accuracy for this fold: 0.6779661016949152
# F1 score for this fold: 0.6791241498758145
# C:\Users\isile\AppData\Local\Temp\ipykernel_14176\4139189586.py:29: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   y_train_temp, y_test_temp = y[train_index], y[test_index]
# Accuracy for this fold: 0.711864406779661
# F1 score for this fold: 0.7129005551520448
# Mean Accuracy: 0.7612994350282485
# Mean F1 Score: 0.761856847791601
# Final common features: {'CTF1.1', 'Unnamed: 10181', 'Unnamed: 23047', 'Unnamed: 1317', 'HCRTR1.1', 'Unnamed: 29600', 'Unnamed: 13614', 'Unnamed: 20232', 'Unnamed: 6699', 'Unnamed: 34788', 'Unnamed: 36080', 'PER3', 'clinico.genetic.subgroup_ST1', 'Unnamed: 4285', 'Unnamed: 32852', 'Unnamed: 13566', 'Unnamed: 27889', 'GPNMB.1', 'Unnamed: 10741', 'MTMR9LP', 'SGPP1.1', 'Unnamed: 29490', 'BCDIN3D', 'Unnamed: 36423', 'RIPK1', 'CILP2', 'Unnamed: 31067', 'Unnamed: 19122', 'Unnamed: 20876', 'Unnamed: 39219', 'ESR1.2', 'Unnamed: 35698', 'Unnamed: 8332', 'Unnamed: 6292', 'ADAMTS7P1|ADAMTS7', 'Unnamed: 18444', 'Unnamed: 42100', 'Unnamed: 27292', 'Unnamed: 7357', 'Unnamed: 32628', 'Unnamed: 34625', 'Unnamed: 41174', 'Unnamed: 18650', 'OR8K3', 'Unnamed: 7285', 'Unnamed: 30904', 'Unnamed: 10081', 'Unnamed: 23425', 'Unnamed: 11786', 'NRTN', 'Unnamed: 26395', 'Unnamed: 27244', 'Unnamed: 32365', 'Unnamed: 44530', 'Unnamed: 2388', 'HPS4', 'Unnamed: 2578', 'Unnamed: 27611', 'Unnamed: 40602', 'Unnamed: 12656', 'DDOST', 'Unnamed: 44043', 'Unnamed: 23282', 'TYW5', 'Unnamed: 5300', 'Unnamed: 7785', 'Unnamed: 15891', 'Unnamed: 29728', 'Unnamed: 38351', 'TMEM80', 'Unnamed: 35402', 'Unnamed: 28941', 'LINC00339', 'Unnamed: 3572', 'Unnamed: 30866', 'R3HDM2', 'SLC16A10', 'Unnamed: 1657', 'Unnamed: 23848', 'Unnamed: 36674', 'Unnamed: 10440', 'Unnamed: 28864', 'ACOT1|ACOT2.1', 'Unnamed: 23410', 'Unnamed: 5824', 'Unnamed: 27880', 'Unnamed: 2268', 'Unnamed: 10459', 'NDUFAF8', 'Unnamed: 25494', 'Unnamed: 23356', 'Unnamed: 19842', 'RAD50|TH2LCRR', 'Unnamed: 11818', 'Unnamed: 34510', 'RFX6', 'Unnamed: 30203', 'DNAH17.1', 'Unnamed: 29915', 'Unnamed: 20602', 'UCKL1-AS1', 'Unnamed: 32978', 'Unnamed: 35736', 'Unnamed: 40562', 'Unnamed: 28434', 'Unnamed: 11059', 'Unnamed: 35911', 'Unnamed: 18517', 'Unnamed: 4714', 'Unnamed: 22643', 'Unnamed: 31810', 'Unnamed: 12303'}

# %%
# # Convert the set to a DataFrame
# final_common_features_df = pd.DataFrame(final_common_features, columns=["FeatureName"])

# # Save it to a CSV file
# final_common_features_df.to_csv("final_common_features_for_Progression.csv", index=False)

# %% [markdown]
# clinico.genetic.subgroup_ST1 was also selected.

# %% [markdown]
# ####  RANDOM FOREST FEATURE IMPORTANCE

# %%
# from sklearn.ensemble import RandomForestClassifier
# from sklearn.model_selection import StratifiedKFold
# import matplotlib.pyplot as plt
# import numpy as np

# # Initialize a Random Forest Classifier
# rfc = RandomForestClassifier(random_state=42)

# # Initialize lists to store feature importances for each fold
# feature_importances = []

# # Initialize StratifiedKFold
# skf = StratifiedKFold(n_splits=5)

# # Iterate over each split
# for train_index, test_index in skf.split(X, y):
#     X_train_temp, X_test_temp = X.iloc[train_index], X.iloc[test_index]
#     y_train_temp, y_test_temp = y[train_index], y[test_index]

#     # Fit the Random Forest Classifier
#     rfc.fit(X_train_temp, y_train_temp)

#     # Get feature importances from the trained model
#     importances = rfc.feature_importances_
#     feature_importances.append(importances)

# # Calculate the mean feature importances across all folds
# mean_feature_importances = np.mean(feature_importances, axis=0)

# # Sort the common features by their corresponding importances in descending order
# sorted_common_features = [X.columns[feature] for feature in sorted(common_features, key=lambda x: mean_feature_importances[x], reverse=False)]

# # Select the top N common features (e.g., top 100 features)
# num_top_features = 100
# top_common_features = sorted_common_features[:num_top_features]

# # Plot the top common feature importances in a horizontal bar chart
# plt.figure(figsize=(10, 6))
# plt.barh(range(len(top_common_features)), [mean_feature_importances[X.columns.get_loc(feature)] for feature in top_common_features], align="center", color="y")
# plt.yticks(range(len(top_common_features)), top_common_features)
# plt.xlabel("Mean Feature Importance")
# plt.ylabel("Feature")
# plt.title("Top Common Feature Importances for Progression")
# plt.show()
# Out:
# C:\Users\isile\AppData\Local\Temp\ipykernel_14176\3068873655.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   y_train_temp, y_test_temp = y[train_index], y[test_index]
# C:\Users\isile\AppData\Local\Temp\ipykernel_14176\3068873655.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   y_train_temp, y_test_temp = y[train_index], y[test_index]
# C:\Users\isile\AppData\Local\Temp\ipykernel_14176\3068873655.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   y_train_temp, y_test_temp = y[train_index], y[test_index]
# C:\Users\isile\AppData\Local\Temp\ipykernel_14176\3068873655.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   y_train_temp, y_test_temp = y[train_index], y[test_index]
# C:\Users\isile\AppData\Local\Temp\ipykernel_14176\3068873655.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   y_train_temp, y_test_temp = y[train_index], y[test_index]

# %% [markdown]
# X_train y_progression

# %% [markdown]
# ### Hyperparameter tuning and Cross Validation

# %% [markdown]
# Stratified Cross-Validation on X_train for multiclass INSS.Stage clinical endpoint, after hyperparameter tuning (cv=3) because stage2 has only 3 samples
#
# Conducting a 3-fold cross-validation on the training dataset after hyperparameter tuning is a prudent approach in machine learning. This practice allows to evaluate the model's generalization performance within the training dataset without risking data leakage from the reserved test data. In addition CV provides a valuable assessment of how well your model performs across different subsets of the training data and seeing the anomalies on the data which offering a reasonable estimate of its potential performance on unseen data. Moreover, comparing the cross-validation results to the initial single random split helps me estimate the consistency of your model's performance and builds confidence in the reliability of that single split. In otherwords, I have performed the train and test split from original data and I have one split for trainset only but in order to understand how this split reflects the overall dataset, this approach is very valuable.

# %% [markdown]
# ##### Set the X and y

# %%
####X feature matrix
#### Import selected features for Progression
selected_features_progression = pd.read_csv("final_common_features_for_Progression.csv",index_col=False)
##
#### Put them in a list
selected_features = selected_features_progression['FeatureName'].tolist()

# # Subset X_train to include only the selected features
X_sub_prog = X_train[selected_features]
X_sub_prog

# X_sub_prog # y_progression
# Out:
#           ACOT1|ACOT2.1  Unnamed: 30203  ADAMTS7P1|ADAMTS7  Unnamed: 32628  \
# ID
# ICGC_466      -1.124859       -0.006859          -0.375139       -0.273456
# ICGC_292       0.041234        0.445906          -0.341789       -0.194083
# ICGC_032      -0.874086       -1.045557           0.450290       -1.190659
# ICGC_408       0.329623        1.111738          -0.708646        0.061676
# ICGC_108       0.429932       -0.546183           0.942213        0.714300
# ...                 ...             ...                ...             ...
# ICGC_309      -1.024550       -0.006859           0.008394       -0.458660
# ICGC_371       0.078850        1.657720          -0.633607        0.705481
# ICGC_107      -0.259693       -1.438398           1.634240       -1.199478
# ICGC_344      -0.447773       -0.479600           1.217357       -1.419959
# ICGC_053      -0.836470        0.425931           1.125642        0.035218
#
#           Unnamed: 11786  Unnamed: 44043  Unnamed: 39219  Unnamed: 34788  \
# ID
# ICGC_466       -1.143211       -0.307002       -0.008313       -0.321406
# ICGC_292       -0.677324       -0.289279        0.096215        0.370106
# ICGC_032       -0.664732       -0.076602       -1.179023       -1.039860
# ICGC_408        0.921803        1.252630        0.347081       -0.339367
# ICGC_108       -0.249211       -0.041156        0.158931        0.253357
# ...                  ...             ...             ...             ...
# ICGC_309       -1.206169       -1.689403       -1.503058       -0.869227
# ICGC_371        0.909211       -0.041156        1.183302        0.042312
# ICGC_107       -0.041451        0.153798       -0.698195       -1.479913
# ICGC_344       -0.041451       -0.041156       -1.304456       -1.003937
# ICGC_053       -0.450676       -0.324725       -1.408983       -0.510000
#
#           Unnamed: 18650     DDOST  ...  Unnamed: 11059  Unnamed: 44530  \
# ID                                  ...
# ICGC_466        0.563923  0.280497  ...       -0.684636       -0.403156
# ICGC_292       -0.402232 -1.498809  ...       -0.752220       -0.228739
# ICGC_032        0.912189  0.772018  ...       -0.904286       -0.239640
# ICGC_408       -0.845989 -1.567622  ...       -0.279127        1.112089
# ICGC_108        0.608861  1.410995  ...        0.177070       -0.261442
# ...                  ...       ...  ...             ...             ...
# ICGC_309        0.260596  0.388631  ...       -1.056352       -0.850098
# ICGC_371        0.771759  0.123210  ...       -0.160854        0.021985
# ICGC_107        1.749149  1.253708  ...        0.599474       -0.272343
# ICGC_344        0.687501  0.555748  ...       -0.279127       -0.762890
# ICGC_053        1.541313 -0.191363  ...       -0.583258       -1.111723
#
#           Unnamed: 13566  Unnamed: 19842  Unnamed: 12303    TMEM80  \
# ID
# ICGC_466       -1.549636        0.262210       -0.905954 -0.086089
# ICGC_292        1.153925       -0.456661       -0.047131 -0.141958
# ICGC_032        0.694320        0.952889       -0.218896 -0.823549
# ICGC_408        0.891294       -1.556111       -0.047131  2.070422
# ICGC_108        0.779289        0.255162       -0.152832 -0.700639
# ...                  ...             ...             ...       ...
# ICGC_309        1.296828        0.614597        0.032145 -0.454819
# ICGC_371        0.018430       -0.773810        0.468163  0.271467
# ICGC_107        1.459042        2.024148       -0.245321  0.204425
# ICGC_344        0.736805        0.332687       -0.958805 -0.700639
# ICGC_053        1.945683        0.480690       -1.447674 -0.957633
#
#           Unnamed: 40602      NRTN  Unnamed: 25494  Unnamed: 36080
# ID
# ICGC_466       -0.694944 -0.015433       -0.559103        0.690619
# ICGC_292       -0.781703 -0.752247       -0.635112       -0.630509
# ICGC_032       -0.261150 -0.811668       -0.837804       -0.999647
# ICGC_408        0.918770  0.115292       -0.027037        0.535192
# ICGC_108       -0.764351  0.578772       -0.090378       -0.863649
# ...                  ...       ...             ...             ...
# ICGC_309       -1.527829 -0.764132       -1.103837       -1.465928
# ICGC_371        1.439324  0.863990        0.631711        1.040330
# ICGC_107       -0.052929 -0.431377       -0.084044        0.010627
# ICGC_344       -0.243798 -1.489062       -1.129173        0.146625
# ICGC_053       -1.736050  0.305437        0.048973       -0.805364
#
# [298 rows x 112 columns]

# %%
# X_sub_prog # y_progression

# %% [markdown]
# #### RANDOM FOREST HYPERPARAMETER TUNING FOR SELECTED FEATURES

# %%
#Import necessary libraries
from sklearn.model_selection import  GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, roc_curve, auc, precision_recall_curve, average_precision_score

##############FOR RANDOM FOREST-HYPER PARAMETER TUNING#########################

# Set the parameters for grid search (for Random Forest) #we can give choices inside in list as much as we want
param_grid = {
    'n_estimators': [100, 200, 300], 
    'max_depth': [3, 5, 7],
    'min_samples_split': [2, 5, 10]#choices 2,5 and 10
}

# Initialize a RandomForestClassifier (define the Random Forest classifier)
rf = RandomForestClassifier(random_state=42)

# Initialize GridSearchCV (define the grid search algorithm)
grid_search = GridSearchCV(estimator=rf, param_grid=param_grid, cv=5) #here in param_grid ,we provide the param_grid that we set above

# Fit GridSearchCV
grid_search.fit(X_sub_prog, y_progression)
#during grid search for train set, every possible combinations of the parameter choices that we set above will be tested.
#And for ever single parameter combination, it will run cross_validation for 5 folds

#after that we obtain the best parameters from the grid search

# Get the best parameters (for the random forest)
best_params = grid_search.best_params_
print('Best parameters for RandomForestClassifier: ', best_params)
# Out:
# Best parameters for RandomForestClassifier:  {'max_depth': 5, 'min_samples_split': 2, 'n_estimators': 100}

# %% [markdown]
# #### RANDOM FOREST CROSS VALIDATION FOR SELECTED FEATURES

# %%
# X_sub_prog # y_progression

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score, roc_curve, roc_auc_score, precision_recall_curve, average_precision_score, confusion_matrix
from sklearn.model_selection import StratifiedKFold
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Create a Random Forest classifier
clf = RandomForestClassifier(**best_params, random_state=42)

# Define the number of folds for cross-validation
n_splits = 3

# Initialize lists to store metrics for each fold
accuracies = []
precisions = []
recalls = []
f1_scores = []
roc_aucs = []
pr_aucs = []

# Initialize variables for mean ROC-AUC and PR-AUC
mean_roc_auc = 0
mean_pr_auc = 0

# Initialize lists to store ROC and PR curves for each fold
roc_curves = []

# Initialize lists to store recall and precision values for each fold
recall_values = []
precision_values = []

# Initialize the list to store confusion matrices for each fold
confusion_matrices = []

# Define your binary class labels
class_labels = y_progression.unique()

# Create a StratifiedKFold object for cross-validation
skf = StratifiedKFold(n_splits=n_splits)

for train_index, test_index in skf.split(X_sub_prog.values, y_progression):
    X_train, X_test = X_sub_prog.iloc[train_index], X_sub_prog.iloc[test_index]
    y_train, y_test = y_progression[train_index], y_progression[test_index]

    # Train the Random Forest classifier
    clf.fit(X_train, y_train)

    # Make predictions on the test set
    y_pred_probs = clf.predict_proba(X_test)
    y_pred = np.argmax(y_pred_probs, axis=1)

    # Calculate accuracy, precision, recall, and F1-score
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred, average='binary')
    recall = recall_score(y_test, y_pred, average='binary')
    f1 = f1_score(y_test, y_pred, average='binary')

    # Store the metrics for this fold
    accuracies.append(accuracy)
    precisions.append(precision)
    recalls.append(recall)
    f1_scores.append(f1)

    # Calculate ROC-AUC for this fold
    fpr, tpr, _ = roc_curve(y_test, y_pred_probs[:, 1])
    roc_auc = roc_auc_score(y_test, y_pred_probs[:, 1])
    roc_aucs.append(roc_auc)
    roc_curves.append((fpr, tpr))

    # Calculate and append the confusion matrix for this fold
    conf_matrix = confusion_matrix(y_test, y_pred)
    confusion_matrices.append(conf_matrix)

    # Calculate Precision-Recall values for this fold
    precision_fold, recall_fold, _ = precision_recall_curve(y_test, y_pred_probs[:, 1])
    recall_values.append(recall_fold)
    precision_values.append(precision_fold)

    # Calculate PR-AUC for this fold
    pr_auc = average_precision_score(y_test, y_pred_probs[:, 1])
    pr_aucs.append(pr_auc)

    # Update mean ROC-AUC and PR-AUC
    mean_roc_auc += roc_auc
    mean_pr_auc += pr_auc

# Calculate mean ROC-AUC and PR-AUC across folds
mean_roc_auc /= n_splits
mean_pr_auc /= n_splits

# Print the confusion matrices for each fold
for i, conf_matrix in enumerate(confusion_matrices):
    confusion_matrix_df = pd.DataFrame(conf_matrix, index=class_labels, columns=class_labels)
    print(f"Confusion Matrix for Fold {i} with Progression:")
    print(confusion_matrix_df)

# Print the mean metrics across folds
print("Mean Accuracy:", np.mean(accuracies))
print("Mean Precision:", np.mean(precisions))
print("Mean Recall:", np.mean(recalls))
print("Mean F1-score:", np.mean(f1_scores))
print("Mean ROC-AUC:", mean_roc_auc)
print("Mean PR-AUC:", mean_pr_auc)

# Plot the ROC curve for each fold and the mean ROC-AUC
plt.figure(figsize=(8, 6))
for i, (fpr, tpr) in enumerate(roc_curves):
    roc_auc = roc_aucs[i]
    plt.plot(fpr, tpr, label=f'Fold {i} (AUC = {roc_auc:.2f})')

plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve (5-Fold Cross-Validation)')
plt.legend(loc='best')
plt.grid()
plt.show()

# Plot the Precision-Recall curves for each fold
plt.figure(figsize=(8, 6))
for i, (recall, precision) in enumerate(zip(recall_values, precision_values)):
    pr_auc = pr_aucs[i]
    plt.plot(recall, precision, label=f'Fold {i} (AUC = {pr_auc:.2f})')

plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curves (5-Fold Cross-Validation)')
plt.legend(loc='best')
plt.grid()
plt.show()
# Out:
# Confusion Matrix for Fold 0 with Progression:
#     1   0
# 1  52   9
# 0  12  27
# Confusion Matrix for Fold 1 with Progression:
#     1   0
# 1  54   6
# 0  12  27
# Confusion Matrix for Fold 2 with Progression:
#     1   0
# 1  42  18
# 0  11  28
# Mean Accuracy: 0.7717508417508419
# Mean Precision: 0.7256258234519105
# Mean Recall: 0.7008547008547009
# Mean F1-score: 0.7096078431372549
# Mean ROC-AUC: 0.8644458455933867
# Mean PR-AUC: 0.8197494743715371

# %% [markdown]
# #### SVM (RADIAL) HYPERPARAMETER TUNING FOR SELECTED FEATURES

# %%
#Import necessary libraries
import numpy as np
import pandas as pd
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, roc_curve, auc, precision_recall_curve, average_precision_score
import optuna #hyperparameter optimizer
import matplotlib.pyplot as plt

# %%
#import the train-test split library
from sklearn.model_selection import train_test_split
# X_sub_prog # y_progression

#Split the data (20% for test, because we have small dataset)
X_train_prog, X_test_prog, y_train_prog, y_test_prog = train_test_split(X_sub_prog, y_progression, test_size=0.2, random_state=1)

# %%
# X_sub_prog # y_progression

# %%
########FOR SUPPORT VECTOR MACHINE-HYPER PARAMETER TUNING (we use optuna) ########################
import optuna

# Define the objective function for optuna
def objective(trial):
    
    C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4 
    gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
    
    svm = SVC(C=C, gamma=gamma, random_state=42, probability=True)
    svm.fit(X_train_prog, y_train_prog)
    predictions = svm.predict(X_test_prog)
    
    return accuracy_score(y_test_prog, predictions)

# Run optuna optimization
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=100)

#We then get the best parameters

# Get the best parameters
best_params = study.best_params
print('Best parameters for SVC: ', best_params)
# Out:
# [I 2023-10-20 20:06:15,475] A new study created in memory with name: no-name-8b8d18fc-d0e6-4220-9d42-92f044b7ad26
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:06:15,503] Trial 0 finished with value: 0.85 and parameters: {'C': 577.8455734459483, 'gamma': 0.014432925245043346}. Best is trial 0 with value: 0.85.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:06:15,531] Trial 1 finished with value: 0.7333333333333333 and parameters: {'C': 590.0056501335275, 'gamma': 0.0004216553004306759}. Best is trial 0 with value: 0.85.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:06:15,567] Trial 2 finished with value: 0.75 and parameters: {'C': 0.4468910346626287, 'gamma': 0.001211094440147057}. Best is trial 0 with value: 0.85.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:06:15,592] Trial 3 finished with value: 0.6 and parameters: {'C': 73.26663717735958, 'gamma': 0.1207093974761633}. Best is trial 0 with value: 0.85.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:06:15,619] Trial 4 finished with value: 0.6 and parameters: {'C': 0.009476383776867459, 'gamma': 33.49134191397971}. Best is trial 0 with value: 0.85.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:06:15,646] Trial 5 finished with value: 0.6 and parameters: {'C': 0.0019262371676580245, 'gamma': 255.08253450341502}. Best is trial 0 with value: 0.85.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:06:15,673] Trial 6 finished with value: 0.6 and parameters: {'C': 8544.113500029289, 'gamma': 80.43690840895968}. Best is trial 0 with value: 0.85.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:06:15,700] Trial 7 finished with value: 0.6 and parameters: {'C': 1305.9579849321176, 'gamma': 43.16061156575692}. Best is trial 0 with value: 0.85.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:06:15,709] Trial 8 finished with value: 0.7666666666666667 and parameters: {'C': 18.040382999370266, 'gamma': 0.00021266369428134054}. Best is trial 0 with value: 0.85.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:06:15,727] Trial 9 finished with value: 0.6 and parameters: {'C': 24.947659328430294, 'gamma': 2.373899490179734}. Best is trial 0 with value: 0.85.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:06:15,744] Trial 10 finished with value: 0.75 and parameters: {'C': 0.44053875803495646, 'gamma': 0.028069838666370313}. Best is trial 0 with value: 0.85.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:06:15,761] Trial 11 finished with value: 0.8 and parameters: {'C': 23.658794332036535, 'gamma': 0.005217507249707097}. Best is trial 0 with value: 0.85.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:06:15,779] Trial 12 finished with value: 0.85 and parameters: {'C': 7.787524327266227, 'gamma': 0.012421247789398642}. Best is trial 0 with value: 0.85.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:06:15,797] Trial 13 finished with value: 0.6 and parameters: {'C': 2.9596249665171994, 'gamma': 0.1543316573233837}. Best is trial 0 with value: 0.85.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:06:15,815] Trial 14 finished with value: 0.8166666666666667 and parameters: {'C': 423.19072770970905, 'gamma': 0.006350574780273802}. Best is trial 0 with value: 0.85.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:06:15,833] Trial 15 finished with value: 0.6 and parameters: {'C': 0.06228858937697262, 'gamma': 0.9868156009091538}. Best is trial 0 with value: 0.85.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:06:15,852] Trial 16 finished with value: 0.6 and parameters: {'C': 0.0001479817413299463, 'gamma': 0.0035724036864330207}. Best is trial 0 with value: 0.85.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:06:15,882] Trial 17 finished with value: 0.6 and parameters: {'C': 3.6663577895205473, 'gamma': 9144.11728348897}. Best is trial 0 with value: 0.85.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:06:15,897] Trial 18 finished with value: 0.85 and parameters: {'C': 181.93485299057147, 'gamma': 0.00013130940219114692}. Best is trial 0 with value: 0.85.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:06:15,918] Trial 19 finished with value: 0.7666666666666667 and parameters: {'C': 2621.3734881029623, 'gamma': 0.042374578400973896}. Best is trial 0 with value: 0.85.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:06:15,939] Trial 20 finished with value: 0.7333333333333333 and parameters: {'C': 9970.104594887232, 'gamma': 0.0007188061589538895}. Best is trial 0 with value: 0.85.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:06:15,954] Trial 21 finished with value: 0.85 and parameters: {'C': 188.80734075330756, 'gamma': 0.00014716632132645994}. Best is trial 0 with value: 0.85.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:06:15,971] Trial 22 finished with value: 0.8333333333333334 and parameters: {'C': 151.2675253132757, 'gamma': 0.00010343226140209946}. Best is trial 0 with value: 0.85.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:06:15,989] Trial 23 finished with value: 0.7666666666666667 and parameters: {'C': 1142.0421504101246, 'gamma': 0.0018665805427050969}. Best is trial 0 with value: 0.85.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:06:16,009] Trial 24 finished with value: 0.85 and parameters: {'C': 79.48207647604359, 'gamma': 0.012478110961020956}. Best is trial 0 with value: 0.85.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:06:16,026] Trial 25 finished with value: 0.8333333333333334 and parameters: {'C': 7.350701619201382, 'gamma': 0.0017853238540074773}. Best is trial 0 with value: 0.85.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:06:16,046] Trial 26 finished with value: 0.7166666666666667 and parameters: {'C': 207.2374025488447, 'gamma': 0.0005790936789755215}. Best is trial 0 with value: 0.85.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:06:16,068] Trial 27 finished with value: 0.85 and parameters: {'C': 47.00153131844961, 'gamma': 0.014181619741449374}. Best is trial 0 with value: 0.85.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:06:16,089] Trial 28 finished with value: 0.7333333333333333 and parameters: {'C': 358.26997900016903, 'gamma': 0.00043500399050619995}. Best is trial 0 with value: 0.85.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:06:16,108] Trial 29 finished with value: 0.7166666666666667 and parameters: {'C': 793.6779682023209, 'gamma': 0.0005596289560280398}. Best is trial 0 with value: 0.85.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:06:16,125] Trial 30 finished with value: 0.85 and parameters: {'C': 6.475478055832416, 'gamma': 0.003341840294658786}. Best is trial 0 with value: 0.85.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:06:16,140] Trial 31 finished with value: 0.85 and parameters: {'C': 165.31234971737425, 'gamma': 0.00017867346195341399}. Best is trial 0 with value: 0.85.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:06:16,156] Trial 32 finished with value: 0.8333333333333334 and parameters: {'C': 89.26832033650639, 'gamma': 0.0001592361351695265}. Best is trial 0 with value: 0.85.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:06:16,176] Trial 33 finished with value: 0.7333333333333333 and parameters: {'C': 407.3874723921506, 'gamma': 0.001192509736984055}. Best is trial 0 with value: 0.85.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:06:16,197] Trial 34 finished with value: 0.7 and parameters: {'C': 2834.908564628639, 'gamma': 0.000353828288690987}. Best is trial 0 with value: 0.85.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:06:16,212] Trial 35 finished with value: 0.7666666666666667 and parameters: {'C': 34.51242652935355, 'gamma': 0.00011952386669786926}. Best is trial 0 with value: 0.85.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:06:16,232] Trial 36 finished with value: 0.7666666666666667 and parameters: {'C': 78.63052464392197, 'gamma': 0.0014595751761832564}. Best is trial 0 with value: 0.85.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:06:16,246] Trial 37 finished with value: 0.7666666666666667 and parameters: {'C': 13.956689734794864, 'gamma': 0.00036537285373989934}. Best is trial 0 with value: 0.85.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:06:16,266] Trial 38 finished with value: 0.7333333333333333 and parameters: {'C': 320.77977418630786, 'gamma': 0.0011139672469173887}. Best is trial 0 with value: 0.85.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:06:16,291] Trial 39 finished with value: 0.6 and parameters: {'C': 2612.564144196812, 'gamma': 0.0851701553564948}. Best is trial 0 with value: 0.85.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:06:16,313] Trial 40 finished with value: 0.8333333333333334 and parameters: {'C': 814.4559611979478, 'gamma': 0.011101747950271395}. Best is trial 0 with value: 0.85.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:06:16,335] Trial 41 finished with value: 0.7666666666666667 and parameters: {'C': 168.02786316904374, 'gamma': 0.0036133912111131162}. Best is trial 0 with value: 0.85.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:06:16,355] Trial 42 finished with value: 0.8333333333333334 and parameters: {'C': 118.2780252470318, 'gamma': 0.021185843813448027}. Best is trial 0 with value: 0.85.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:06:16,377] Trial 43 finished with value: 0.8333333333333334 and parameters: {'C': 54.54803941536148, 'gamma': 0.008190554756669681}. Best is trial 0 with value: 0.85.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:06:16,398] Trial 44 finished with value: 0.7833333333333333 and parameters: {'C': 41.95104049329174, 'gamma': 0.033973832801472655}. Best is trial 0 with value: 0.85.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:06:16,424] Trial 45 finished with value: 0.8333333333333334 and parameters: {'C': 15.8317730997789, 'gamma': 0.009313340370212225}. Best is trial 0 with value: 0.85.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:06:16,447] Trial 46 finished with value: 0.6 and parameters: {'C': 1.9586174338228635, 'gamma': 0.15127475848108682}. Best is trial 0 with value: 0.85.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:06:16,467] Trial 47 finished with value: 0.85 and parameters: {'C': 84.73421813682933, 'gamma': 0.000290442968781766}. Best is trial 0 with value: 0.85.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:06:16,492] Trial 48 finished with value: 0.6 and parameters: {'C': 27.374108814958305, 'gamma': 0.307178499095363}. Best is trial 0 with value: 0.85.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:06:16,511] Trial 49 finished with value: 0.7833333333333333 and parameters: {'C': 1.0813702968704946, 'gamma': 0.003061862111272681}. Best is trial 0 with value: 0.85.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:06:16,537] Trial 50 finished with value: 0.8333333333333334 and parameters: {'C': 540.3164752450798, 'gamma': 0.017952187940668562}. Best is trial 0 with value: 0.85.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:06:16,561] Trial 51 finished with value: 0.75 and parameters: {'C': 56.32847601680452, 'gamma': 0.05324721663474015}. Best is trial 0 with value: 0.85.
# ...
# [I 2023-10-20 20:06:17,179] Trial 82 finished with value: 0.85 and parameters: {'C': 68.78324659530765, 'gamma': 0.0002820749910137533}. Best is trial 0 with value: 0.85.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:06:17,201] Trial 83 finished with value: 0.7333333333333333 and parameters: {'C': 325.5599010611925, 'gamma': 0.0008279579880602809}. Best is trial 0 with value: 0.85.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:06:17,218] Trial 84 finished with value: 0.85 and parameters: {'C': 30.634028481349457, 'gamma': 0.0003840611720613663}. Best is trial 0 with value: 0.85.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:06:17,242] Trial 85 finished with value: 0.7833333333333333 and parameters: {'C': 86.73884904995377, 'gamma': 0.03651991480306327}. Best is trial 0 with value: 0.85.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:06:17,264] Trial 86 finished with value: 0.85 and parameters: {'C': 148.81271846030984, 'gamma': 0.0001839043863847606}. Best is trial 0 with value: 0.85.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:06:17,282] Trial 87 finished with value: 0.8333333333333334 and parameters: {'C': 11.846223752171529, 'gamma': 0.0011921130575309814}. Best is trial 0 with value: 0.85.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:06:17,307] Trial 88 finished with value: 0.8333333333333334 and parameters: {'C': 1233.504238635122, 'gamma': 0.025208664768920558}. Best is trial 0 with value: 0.85.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:06:17,329] Trial 89 finished with value: 0.7666666666666667 and parameters: {'C': 48.85728902457236, 'gamma': 0.0025521671989526666}. Best is trial 0 with value: 0.85.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:06:17,349] Trial 90 finished with value: 0.85 and parameters: {'C': 4.679675420052178, 'gamma': 0.005698660389911118}. Best is trial 0 with value: 0.85.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:06:17,368] Trial 91 finished with value: 0.85 and parameters: {'C': 6.164382650228627, 'gamma': 0.0034116948696634934}. Best is trial 0 with value: 0.85.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:06:17,390] Trial 92 finished with value: 0.85 and parameters: {'C': 21.89035870086918, 'gamma': 0.012688795197355638}. Best is trial 0 with value: 0.85.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:06:17,406] Trial 93 finished with value: 0.7833333333333333 and parameters: {'C': 2.7945864371504894, 'gamma': 0.0005764996999356166}. Best is trial 0 with value: 0.85.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:06:17,423] Trial 94 finished with value: 0.85 and parameters: {'C': 8.4146443492099, 'gamma': 0.00170848582930299}. Best is trial 0 with value: 0.85.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:06:17,447] Trial 95 finished with value: 0.85 and parameters: {'C': 213.71387980413976, 'gamma': 0.00014753898981331612}. Best is trial 0 with value: 0.85.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:06:17,470] Trial 96 finished with value: 0.7666666666666667 and parameters: {'C': 390.36052491065817, 'gamma': 0.0024050590193630396}. Best is trial 0 with value: 0.85.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:06:17,491] Trial 97 finished with value: 0.8333333333333334 and parameters: {'C': 39.190263650211435, 'gamma': 0.00818305821347697}. Best is trial 0 with value: 0.85.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:06:17,510] Trial 98 finished with value: 0.75 and parameters: {'C': 95.13937671873076, 'gamma': 0.0010237622419834082}. Best is trial 0 with value: 0.85.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\2670709075.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:06:17,533] Trial 99 finished with value: 0.8333333333333334 and parameters: {'C': 644.2053751319813, 'gamma': 0.01771452234660798}. Best is trial 0 with value: 0.85.
# Best parameters for SVC:  {'C': 577.8455734459483, 'gamma': 0.014432925245043346}

# %%
# X_sub_prog # y_progression

# %% [markdown]
# #### SVM (RADIAL) CROSS VALIDATION FOR SELECTED FEATURES

# %%
from sklearn.svm import SVC
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score, roc_curve, roc_auc_score, precision_recall_curve, average_precision_score, confusion_matrix
from sklearn.model_selection import StratifiedKFold
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Create a SVM classifier
# Specify hyperparameters
# C_value = 577.8455734459483
# gamma_value = 0.014432925245043346

# Create a SVM classifier
clf = SVC(**best_params, random_state=42, probability=True)

# Define the number of folds for cross-validation
n_splits = 3

# Initialize lists to store metrics for each fold
accuracies = []
precisions = []
recalls = []
f1_scores = []
roc_aucs = []
pr_aucs = []

# Initialize variables for mean ROC-AUC and PR-AUC
mean_roc_auc = 0
mean_pr_auc = 0

# Initialize lists to store ROC and PR curves for each fold
roc_curves = []

# Initialize lists to store recall and precision values for each fold
recall_values = []
precision_values = []

# Initialize the list to store confusion matrices for each fold
confusion_matrices = []

# Define your binary class labels
class_labels = y_progression.unique()

# Create a StratifiedKFold object for cross-validation
skf = StratifiedKFold(n_splits=n_splits)

for train_index, test_index in skf.split(X_sub_prog.values, y_progression):
    X_train, X_test = X_sub_prog.iloc[train_index], X_sub_prog.iloc[test_index]
    y_train, y_test = y_progression[train_index], y_progression[test_index]

    # Train the Random Forest classifier
    clf.fit(X_train, y_train)

    # Make predictions on the test set
    y_pred_probs = clf.predict_proba(X_test)
    y_pred = np.argmax(y_pred_probs, axis=1)

    # Calculate accuracy, precision, recall, and F1-score
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred, average='binary')
    recall = recall_score(y_test, y_pred, average='binary')
    f1 = f1_score(y_test, y_pred, average='binary')

    # Store the metrics for this fold
    accuracies.append(accuracy)
    precisions.append(precision)
    recalls.append(recall)
    f1_scores.append(f1)

    # Calculate ROC-AUC for this fold
    fpr, tpr, _ = roc_curve(y_test, y_pred_probs[:, 1])
    roc_auc = roc_auc_score(y_test, y_pred_probs[:, 1])
    roc_aucs.append(roc_auc)
    roc_curves.append((fpr, tpr))

    # Calculate and append the confusion matrix for this fold
    conf_matrix = confusion_matrix(y_test, y_pred)
    confusion_matrices.append(conf_matrix)

    # Calculate Precision-Recall values for this fold
    precision_fold, recall_fold, _ = precision_recall_curve(y_test, y_pred_probs[:, 1])
    recall_values.append(recall_fold)
    precision_values.append(precision_fold)

    # Calculate PR-AUC for this fold
    pr_auc = average_precision_score(y_test, y_pred_probs[:, 1])
    pr_aucs.append(pr_auc)

    # Update mean ROC-AUC and PR-AUC
    mean_roc_auc += roc_auc
    mean_pr_auc += pr_auc

# Calculate mean ROC-AUC and PR-AUC across folds
mean_roc_auc /= n_splits
mean_pr_auc /= n_splits

# Print the confusion matrices for each fold
for i, conf_matrix in enumerate(confusion_matrices):
    confusion_matrix_df = pd.DataFrame(conf_matrix, index=class_labels, columns=class_labels)
    print(f"Confusion Matrix for Fold {i} with Progression:")
    print(confusion_matrix_df)

# Print the mean metrics across folds
print("Mean Accuracy:", np.mean(accuracies))
print("Mean Precision:", np.mean(precisions))
print("Mean Recall:", np.mean(recalls))
print("Mean F1-score:", np.mean(f1_scores))
print("Mean ROC-AUC:", mean_roc_auc)
print("Mean PR-AUC:", mean_pr_auc)

# Plot the ROC curve for each fold and the mean ROC-AUC
plt.figure(figsize=(8, 6))
for i, (fpr, tpr) in enumerate(roc_curves):
    roc_auc = roc_aucs[i]
    plt.plot(fpr, tpr, label=f'Fold {i} (AUC = {roc_auc:.2f})')

plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve (5-Fold Cross-Validation)')
plt.legend(loc='best')
plt.grid()
plt.show()

# Plot the Precision-Recall curves for each fold
plt.figure(figsize=(8, 6))
for i, (recall, precision) in enumerate(zip(recall_values, precision_values)):
    pr_auc = pr_aucs[i]
    plt.plot(recall, precision, label=f'Fold {i} (AUC = {pr_auc:.2f})')

plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curves (5-Fold Cross-Validation)')
plt.legend(loc='best')
plt.grid()
plt.show()
# Out:
# Confusion Matrix for Fold 0 with Progression:
#     1   0
# 1  55   6
# 0  15  24
# Confusion Matrix for Fold 1 with Progression:
#     1   0
# 1  55   5
# 0  16  23
# Confusion Matrix for Fold 2 with Progression:
#     1   0
# 1  41  19
# 0  13  26
# Mean Accuracy: 0.7515488215488215
# Mean Precision: 0.7330687830687831
# Mean Recall: 0.6239316239316239
# Mean F1-score: 0.6670889857132557
# Mean ROC-AUC: 0.8325393489327916
# Mean PR-AUC: 0.7600627534193243

# %% [markdown]
# #### LOGISTIC REGRESSION HYPERPARAMETER TUNING FOR SELECTED FEATURES

# %%
# X_sub_prog # y_progression

# %%
##############FOR LOGISTIC REGRESSION-HYPER PARAMETER TUNING #########################
from sklearn.linear_model import LogisticRegression
# Set the parameters for random search (for logistic regression)
param_grid = {
    'C': np.logspace(-4, 4, 20),#this search is really large space
    'penalty': ['l1'], #l1 loss
    'solver': ['liblinear']
}

# Initialize a LogisticRegression (define the Logistic regression classifier)
lr = LogisticRegression(random_state=42)

# Initialize Grid_SearchCV (define the random search algorithm#this time we want to use Random serach because we dont want to search the all the combinations)
grid_search = GridSearchCV(estimator=lr, param_grid=param_grid, cv=5)

# Fit Grid_SearchCV
grid_search.fit(X_sub_prog, y_progression)

#after that we  obtain the best parameters from the random search

# Get the best parameters
best_params = grid_search.best_params_
print('Best parameters for LogisticRegression: ', best_params)
# Out:
# Best parameters for LogisticRegression:  {'C': 0.23357214690901212, 'penalty': 'l1', 'solver': 'liblinear'}

# %%
# X_sub_prog # y_progression

# %% [markdown]
# #### LOGISTIC REGRESSION CROSS VALIDATION FOR SELECTED FEATURES

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score, roc_curve, roc_auc_score, precision_recall_curve, average_precision_score, confusion_matrix
from sklearn.model_selection import StratifiedKFold
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Create a Random Forest classifier
clf = LogisticRegression(**best_params, random_state=42)

# Define the number of folds for cross-validation
n_splits = 3

# Initialize lists to store metrics for each fold
accuracies = []
precisions = []
recalls = []
f1_scores = []
roc_aucs = []
pr_aucs = []

# Initialize variables for mean ROC-AUC and PR-AUC
mean_roc_auc = 0
mean_pr_auc = 0

# Initialize lists to store ROC and PR curves for each fold
roc_curves = []

# Initialize lists to store recall and precision values for each fold
recall_values = []
precision_values = []

# Initialize the list to store confusion matrices for each fold
confusion_matrices = []

# Define your binary class labels
class_labels = y_progression.unique()

# Create a StratifiedKFold object for cross-validation
skf = StratifiedKFold(n_splits=n_splits)

for train_index, test_index in skf.split(X_sub_prog.values, y_progression):
    X_train, X_test = X_sub_prog.iloc[train_index], X_sub_prog.iloc[test_index]
    y_train, y_test = y_progression[train_index], y_progression[test_index]

    # Train the Random Forest classifier
    clf.fit(X_train, y_train)

    # Make predictions on the test set
    y_pred_probs = clf.predict_proba(X_test)
    y_pred = np.argmax(y_pred_probs, axis=1)

    # Calculate accuracy, precision, recall, and F1-score
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred, average='binary')
    recall = recall_score(y_test, y_pred, average='binary')
    f1 = f1_score(y_test, y_pred, average='binary')

    # Store the metrics for this fold
    accuracies.append(accuracy)
    precisions.append(precision)
    recalls.append(recall)
    f1_scores.append(f1)

    # Calculate ROC-AUC for this fold
    fpr, tpr, _ = roc_curve(y_test, y_pred_probs[:, 1])
    roc_auc = roc_auc_score(y_test, y_pred_probs[:, 1])
    roc_aucs.append(roc_auc)
    roc_curves.append((fpr, tpr))

    # Calculate and append the confusion matrix for this fold
    conf_matrix = confusion_matrix(y_test, y_pred)
    confusion_matrices.append(conf_matrix)

    # Calculate Precision-Recall values for this fold
    precision_fold, recall_fold, _ = precision_recall_curve(y_test, y_pred_probs[:, 1])
    recall_values.append(recall_fold)
    precision_values.append(precision_fold)

    # Calculate PR-AUC for this fold
    pr_auc = average_precision_score(y_test, y_pred_probs[:, 1])
    pr_aucs.append(pr_auc)

    # Update mean ROC-AUC and PR-AUC
    mean_roc_auc += roc_auc
    mean_pr_auc += pr_auc

# Calculate mean ROC-AUC and PR-AUC across folds
mean_roc_auc /= n_splits
mean_pr_auc /= n_splits

# Print the confusion matrices for each fold
for i, conf_matrix in enumerate(confusion_matrices):
    confusion_matrix_df = pd.DataFrame(conf_matrix, index=class_labels, columns=class_labels)
    print(f"Confusion Matrix for Fold {i} with Progression:")
    print(confusion_matrix_df)

# Print the mean metrics across folds
print("Mean Accuracy:", np.mean(accuracies))
print("Mean Precision:", np.mean(precisions))
print("Mean Recall:", np.mean(recalls))
print("Mean F1-score:", np.mean(f1_scores))
print("Mean ROC-AUC:", mean_roc_auc)
print("Mean PR-AUC:", mean_pr_auc)

# Plot the ROC curve for each fold and the mean ROC-AUC
plt.figure(figsize=(8, 6))
for i, (fpr, tpr) in enumerate(roc_curves):
    roc_auc = roc_aucs[i]
    plt.plot(fpr, tpr, label=f'Fold {i} (AUC = {roc_auc:.2f})')

plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve (5-Fold Cross-Validation)')
plt.legend(loc='best')
plt.grid()
plt.show()

# Plot the Precision-Recall curves for each fold
plt.figure(figsize=(8, 6))
for i, (recall, precision) in enumerate(zip(recall_values, precision_values)):
    pr_auc = pr_aucs[i]
    plt.plot(recall, precision, label=f'Fold {i} (AUC = {pr_auc:.2f})')

plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curves (5-Fold Cross-Validation)')
plt.legend(loc='best')
plt.grid()
plt.show()
# Out:
# Confusion Matrix for Fold 0 with Progression:
#     1   0
# 1  54   7
# 0   7  32
# Confusion Matrix for Fold 1 with Progression:
#     1   0
# 1  52   8
# 0   9  30
# Confusion Matrix for Fold 2 with Progression:
#     1   0
# 1  42  18
# 0  11  28
# Mean Accuracy: 0.7984511784511784
# Mean Precision: 0.7395607189657533
# Mean Recall: 0.7692307692307693
# Mean F1-score: 0.7528523763817881
# Mean ROC-AUC: 0.8719303161926112
# Mean PR-AUC: 0.8152596916753535

# %% [markdown]
# ### HYPER PARAMETER TUNING AND CROSS VALIDATION FOR ALL FEATURES

# %% [markdown]
# #### For all Features (no selection) for Progression

# %%
X_train=pd.read_csv("X_train.csv", index_col="ID")
y_train=pd.read_csv("y_train.csv", index_col="ID")

X_all_progression=X_train.copy()

from sklearn.preprocessing import LabelEncoder
# #only get one target
y_progression=y_train["Progression"]

# Initialize the LabelEncoder
label_encoder = LabelEncoder()

# Fit and transform the class labels to numeric values
y_progression_encode = label_encoder.fit_transform(y_progression)

# Now, if you want to get the original labels from the encoded values:
original_labels = label_encoder.inverse_transform(y_progression_encode)

# %%
# X_all_progression # y_progression

# %% [markdown]
# #### RANDOM FOREST HYPER PARAMETER TUNING FOR ALL FEATURES

# %%
#Import necessary libraries
from sklearn.model_selection import  GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, roc_curve, auc, precision_recall_curve, average_precision_score

##############FOR RANDOM FOREST-HYPER PARAMETER TUNING#########################

# Set the parameters for grid search (for Random Forest) #we can give choices inside in list as much as we want
param_grid = {
    'n_estimators': [100, 200, 300], 
    'max_depth': [3, 5, 7],
    'min_samples_split': [2, 5, 10]#choices 2,5 and 10
}

# Initialize a RandomForestClassifier (define the Random Forest classifier)
rf = RandomForestClassifier(random_state=42)

# Initialize GridSearchCV (define the grid search algorithm)
grid_search = GridSearchCV(estimator=rf, param_grid=param_grid, cv=5) #here in param_grid ,we provide the param_grid that we set above

# Fit GridSearchCV
grid_search.fit(X_all_progression, y_progression)
#during grid search for train set, every possible combinations of the parameter choices that we set above will be tested.
#And for ever single parameter combination, it will run cross_validation for 5 folds

#after that we obtain the best parameters from the grid search

# Get the best parameters (for the random forest)
best_params = grid_search.best_params_
print('Best parameters for RandomForestClassifier: ', best_params)
# Out:
# Best parameters for RandomForestClassifier:  {'max_depth': 7, 'min_samples_split': 2, 'n_estimators': 100}

# %% [markdown]
# #### RANDOM FOREST CROSS VALIDATION FOR ALL FEATURES

# %%
# X_all_progression # y_progression

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score, roc_curve, roc_auc_score, precision_recall_curve, average_precision_score, confusion_matrix
from sklearn.model_selection import StratifiedKFold
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Create a Random Forest classifier
clf = RandomForestClassifier(**best_params, random_state=42)

# Define the number of folds for cross-validation
n_splits = 3

# Initialize lists to store metrics for each fold
accuracies = []
precisions = []
recalls = []
f1_scores = []
roc_aucs = []
pr_aucs = []

# Initialize variables for mean ROC-AUC and PR-AUC
mean_roc_auc = 0
mean_pr_auc = 0

# Initialize lists to store ROC and PR curves for each fold
roc_curves = []

# Initialize lists to store recall and precision values for each fold
recall_values = []
precision_values = []

# Initialize the list to store confusion matrices for each fold
confusion_matrices = []

# Define your binary class labels
class_labels = y_progression.unique()

# Create a StratifiedKFold object for cross-validation
skf = StratifiedKFold(n_splits=n_splits)

for train_index, test_index in skf.split(X_all_progression.values, y_progression):
    X_train, X_test = X_all_progression.iloc[train_index], X_all_progression.iloc[test_index]
    y_train, y_test = y_progression[train_index], y_progression[test_index]

    # Train the Random Forest classifier
    clf.fit(X_train, y_train)

    # Make predictions on the test set
    y_pred_probs = clf.predict_proba(X_test)
    y_pred = np.argmax(y_pred_probs, axis=1)

    # Calculate accuracy, precision, recall, and F1-score
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred, average='binary')
    recall = recall_score(y_test, y_pred, average='binary')
    f1 = f1_score(y_test, y_pred, average='binary')

    # Store the metrics for this fold
    accuracies.append(accuracy)
    precisions.append(precision)
    recalls.append(recall)
    f1_scores.append(f1)

    # Calculate ROC-AUC for this fold
    fpr, tpr, _ = roc_curve(y_test, y_pred_probs[:, 1])
    roc_auc = roc_auc_score(y_test, y_pred_probs[:, 1])
    roc_aucs.append(roc_auc)
    roc_curves.append((fpr, tpr))

    # Calculate and append the confusion matrix for this fold
    conf_matrix = confusion_matrix(y_test, y_pred)
    confusion_matrices.append(conf_matrix)

    # Calculate Precision-Recall values for this fold
    precision_fold, recall_fold, _ = precision_recall_curve(y_test, y_pred_probs[:, 1])
    recall_values.append(recall_fold)
    precision_values.append(precision_fold)

    # Calculate PR-AUC for this fold
    pr_auc = average_precision_score(y_test, y_pred_probs[:, 1])
    pr_aucs.append(pr_auc)

    # Update mean ROC-AUC and PR-AUC
    mean_roc_auc += roc_auc
    mean_pr_auc += pr_auc

# Calculate mean ROC-AUC and PR-AUC across folds
mean_roc_auc /= n_splits
mean_pr_auc /= n_splits

# Print the confusion matrices for each fold
for i, conf_matrix in enumerate(confusion_matrices):
    confusion_matrix_df = pd.DataFrame(conf_matrix, index=class_labels, columns=class_labels)
    print(f"Confusion Matrix for Fold {i} with Progression:")
    print(confusion_matrix_df)

# Print the mean metrics across folds
print("Mean Accuracy:", np.mean(accuracies))
print("Mean Precision:", np.mean(precisions))
print("Mean Recall:", np.mean(recalls))
print("Mean F1-score:", np.mean(f1_scores))
print("Mean ROC-AUC:", mean_roc_auc)
print("Mean PR-AUC:", mean_pr_auc)

# Plot the ROC curve for each fold and the mean ROC-AUC
plt.figure(figsize=(8, 6))
for i, (fpr, tpr) in enumerate(roc_curves):
    roc_auc = roc_aucs[i]
    plt.plot(fpr, tpr, label=f'Fold {i} (AUC = {roc_auc:.2f})')

plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve (5-Fold Cross-Validation)')
plt.legend(loc='best')
plt.grid()
plt.show()

# Plot the Precision-Recall curves for each fold
plt.figure(figsize=(8, 6))
for i, (recall, precision) in enumerate(zip(recall_values, precision_values)):
    pr_auc = pr_aucs[i]
    plt.plot(recall, precision, label=f'Fold {i} (AUC = {pr_auc:.2f})')

plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curves (5-Fold Cross-Validation)')
plt.legend(loc='best')
plt.grid()
plt.show()
# Out:
# Confusion Matrix for Fold 0 with Progression:
#     1   0
# 1  55   6
# 0  13  26
# Confusion Matrix for Fold 1 with Progression:
#     1   0
# 1  57   3
# 0  18  21
# Confusion Matrix for Fold 2 with Progression:
#     1   0
# 1  43  17
# 0  14  25
# Mean Accuracy: 0.7615824915824915
# Mean Precision: 0.7609126984126985
# Mean Recall: 0.6153846153846154
# Mean F1-score: 0.6721149944937114
# Mean ROC-AUC: 0.8437555462145626
# Mean PR-AUC: 0.7960181092946197

# %%
# X_all_progression # y_progression

# %% [markdown]
# #### SVM (RADIAL) HYPERPARAMETER TUNING FOR All FEATURES

# %%
#Import necessary libraries
import numpy as np
import pandas as pd
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, roc_curve, auc, precision_recall_curve, average_precision_score
import optuna #hyperparameter optimizer
import matplotlib.pyplot as plt

# %%
#import the train-test split library
from sklearn.model_selection import train_test_split
# X_all_progression # y_progression


#Split the data (20% for test, because we have small dataset)
X_train_all_progression, X_test_all_progression, y_train_progression, y_test_progression = train_test_split(X_all_progression, y_progression, test_size=0.2, random_state=1)

#Check the dimensions of the data

# %%
########FOR SUPPORT VECTOR MACHINE-HYPER PARAMETER TUNING (we use optuna) ########################
import optuna

# Define the objective function for optuna
def objective(trial):
    
    C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4 
    gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
    
    svm = SVC(C=C, gamma=gamma, random_state=42, probability=True)
    svm.fit(X_train_all_progression, y_train_progression)
    predictions = svm.predict(X_test_all_progression)
    
    return accuracy_score(y_test_progression, predictions)

# Run optuna optimization
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=100)

#We then get the best parameters

# Get the best parameters
best_params = study.best_params
print('Best parameters for SVC: ', best_params)
# Out:
# [I 2023-10-20 20:34:25,500] A new study created in memory with name: no-name-4ff94d6a-de57-48e1-bc71-424a7bc90a9d
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:34:28,784] Trial 0 finished with value: 0.6 and parameters: {'C': 0.0019264458060227832, 'gamma': 1.0929230275330446}. Best is trial 0 with value: 0.6.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:34:32,163] Trial 1 finished with value: 0.6 and parameters: {'C': 0.0012058460764689442, 'gamma': 24.94650170467443}. Best is trial 0 with value: 0.6.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:34:35,330] Trial 2 finished with value: 0.6 and parameters: {'C': 0.041246384640736544, 'gamma': 50.07063605473924}. Best is trial 0 with value: 0.6.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:34:38,538] Trial 3 finished with value: 0.6 and parameters: {'C': 0.3342360622918743, 'gamma': 0.028958585159475216}. Best is trial 0 with value: 0.6.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:34:41,836] Trial 4 finished with value: 0.6 and parameters: {'C': 3921.0776557208646, 'gamma': 1434.5714918569763}. Best is trial 0 with value: 0.6.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:34:44,999] Trial 5 finished with value: 0.6 and parameters: {'C': 0.14913016257867262, 'gamma': 250.3282189665069}. Best is trial 0 with value: 0.6.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:34:48,082] Trial 6 finished with value: 0.6 and parameters: {'C': 8328.401532268294, 'gamma': 4597.172932482912}. Best is trial 0 with value: 0.6.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:34:50,524] Trial 7 finished with value: 0.6 and parameters: {'C': 0.000985681071036765, 'gamma': 8.179913635937318}. Best is trial 0 with value: 0.6.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:34:53,084] Trial 8 finished with value: 0.6 and parameters: {'C': 0.00016817544373862593, 'gamma': 0.15116812981773847}. Best is trial 0 with value: 0.6.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:34:56,195] Trial 9 finished with value: 0.6 and parameters: {'C': 9251.189142267527, 'gamma': 4.860030538012259}. Best is trial 0 with value: 0.6.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:34:59,360] Trial 10 finished with value: 0.6 and parameters: {'C': 4.398828816291574, 'gamma': 0.00026891110383451964}. Best is trial 0 with value: 0.6.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:35:02,515] Trial 11 finished with value: 0.6 and parameters: {'C': 0.002930101244617551, 'gamma': 0.8244020743338593}. Best is trial 0 with value: 0.6.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:35:05,643] Trial 12 finished with value: 0.6 and parameters: {'C': 0.006841895696273513, 'gamma': 70.46380542956848}. Best is trial 0 with value: 0.6.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:35:08,123] Trial 13 finished with value: 0.6 and parameters: {'C': 0.00020343494392273964, 'gamma': 1.2540018152497228}. Best is trial 0 with value: 0.6.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:35:10,639] Trial 14 finished with value: 0.6 and parameters: {'C': 0.00010199450683214459, 'gamma': 0.022178042268910732}. Best is trial 0 with value: 0.6.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:35:13,806] Trial 15 finished with value: 0.6 and parameters: {'C': 0.012836396312957738, 'gamma': 15.006911844141746}. Best is trial 0 with value: 0.6.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:35:16,952] Trial 16 finished with value: 0.6 and parameters: {'C': 0.001426440700773607, 'gamma': 1229.7173500514052}. Best is trial 0 with value: 0.6.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:35:20,069] Trial 17 finished with value: 0.6 and parameters: {'C': 0.04428375392885196, 'gamma': 351.7117408645569}. Best is trial 0 with value: 0.6.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:35:23,211] Trial 18 finished with value: 0.6 and parameters: {'C': 1.4201041586693792, 'gamma': 53.25209797955595}. Best is trial 0 with value: 0.6.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:35:25,693] Trial 19 finished with value: 0.6 and parameters: {'C': 0.0008780473055604944, 'gamma': 0.40269061356591646}. Best is trial 0 with value: 0.6.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:35:28,874] Trial 20 finished with value: 0.6 and parameters: {'C': 0.007428473229259552, 'gamma': 2.802485047534786}. Best is trial 0 with value: 0.6.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:35:32,090] Trial 21 finished with value: 0.6 and parameters: {'C': 0.03859185054713131, 'gamma': 24.32153506522698}. Best is trial 0 with value: 0.6.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:35:34,647] Trial 22 finished with value: 0.6 and parameters: {'C': 0.0009615926232467092, 'gamma': 143.802870505084}. Best is trial 0 with value: 0.6.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:35:37,781] Trial 23 finished with value: 0.6 and parameters: {'C': 0.0158387785215082, 'gamma': 16.740827645780687}. Best is trial 0 with value: 0.6.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:35:40,883] Trial 24 finished with value: 0.6 and parameters: {'C': 0.0038050730830364496, 'gamma': 43.47997991962403}. Best is trial 0 with value: 0.6.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:35:44,047] Trial 25 finished with value: 0.6 and parameters: {'C': 0.05270100527468854, 'gamma': 5.099302254828352}. Best is trial 0 with value: 0.6.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:35:46,582] Trial 26 finished with value: 0.6 and parameters: {'C': 0.0005259913184230289, 'gamma': 283.93743794493906}. Best is trial 0 with value: 0.6.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:35:49,102] Trial 27 finished with value: 0.6 and parameters: {'C': 0.0003623093471390139, 'gamma': 8398.332406189005}. Best is trial 0 with value: 0.6.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:35:52,230] Trial 28 finished with value: 0.6 and parameters: {'C': 0.0027432444283643164, 'gamma': 2.2992898042353715}. Best is trial 0 with value: 0.6.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:35:55,397] Trial 29 finished with value: 0.6 and parameters: {'C': 0.30020263261799807, 'gamma': 10.32566502614602}. Best is trial 0 with value: 0.6.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:35:57,822] Trial 30 finished with value: 0.6 and parameters: {'C': 0.00034546320837496237, 'gamma': 56.831421404973675}. Best is trial 0 with value: 0.6.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:36:00,934] Trial 31 finished with value: 0.6 and parameters: {'C': 12.217159241334977, 'gamma': 0.1622839297929194}. Best is trial 0 with value: 0.6.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:36:04,116] Trial 32 finished with value: 0.6 and parameters: {'C': 0.20831811984871856, 'gamma': 881.5760947783281}. Best is trial 0 with value: 0.6.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:36:07,285] Trial 33 finished with value: 0.6 and parameters: {'C': 0.02339908606086561, 'gamma': 0.01848935327222306}. Best is trial 0 with value: 0.6.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:36:10,424] Trial 34 finished with value: 0.6 and parameters: {'C': 0.1056414859741595, 'gamma': 2873.224772548669}. Best is trial 0 with value: 0.6.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:36:13,564] Trial 35 finished with value: 0.6 and parameters: {'C': 0.3755289095644054, 'gamma': 152.92225332181914}. Best is trial 0 with value: 0.6.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:36:16,736] Trial 36 finished with value: 0.6 and parameters: {'C': 0.007862340601127222, 'gamma': 10.912018919299928}. Best is trial 0 with value: 0.6.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:36:19,931] Trial 37 finished with value: 0.6 and parameters: {'C': 0.0022393279774084313, 'gamma': 4.102402843558923}. Best is trial 0 with value: 0.6.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:36:23,071] Trial 38 finished with value: 0.6 and parameters: {'C': 0.08537501743224786, 'gamma': 1.049633392126931}. Best is trial 0 with value: 0.6.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:36:26,219] Trial 39 finished with value: 0.6 and parameters: {'C': 0.02821255033470564, 'gamma': 0.369703093739832}. Best is trial 0 with value: 0.6.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:36:29,412] Trial 40 finished with value: 0.6 and parameters: {'C': 0.006122324484938984, 'gamma': 0.034133530720204655}. Best is trial 0 with value: 0.6.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:36:32,606] Trial 41 finished with value: 0.6 and parameters: {'C': 825.435186403909, 'gamma': 651.6072647090241}. Best is trial 0 with value: 0.6.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:36:35,846] Trial 42 finished with value: 0.6 and parameters: {'C': 4020.1132069347154, 'gamma': 2702.026496234543}. Best is trial 0 with value: 0.6.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:36:38,995] Trial 43 finished with value: 0.6 and parameters: {'C': 0.61310184342585, 'gamma': 102.32273528939308}. Best is trial 0 with value: 0.6.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:36:42,129] Trial 44 finished with value: 0.6 and parameters: {'C': 0.15310383908817976, 'gamma': 8991.457564019618}. Best is trial 0 with value: 0.6.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:36:44,613] Trial 45 finished with value: 0.6 and parameters: {'C': 0.00012741931047110527, 'gamma': 21.229412381413596}. Best is trial 0 with value: 0.6.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:36:47,726] Trial 46 finished with value: 0.6 and parameters: {'C': 1.3129642920147049, 'gamma': 523.09876230508}. Best is trial 0 with value: 0.6.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:36:50,935] Trial 47 finished with value: 0.6 and parameters: {'C': 0.0010636648467279206, 'gamma': 34.11473937109197}. Best is trial 0 with value: 0.6.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:36:54,057] Trial 48 finished with value: 0.6 and parameters: {'C': 12.704640424103955, 'gamma': 186.878465317656}. Best is trial 0 with value: 0.6.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:36:57,196] Trial 49 finished with value: 0.6 and parameters: {'C': 0.011845854937249871, 'gamma': 1853.5508151536865}. Best is trial 0 with value: 0.6.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:37:00,318] Trial 50 finished with value: 0.6 and parameters: {'C': 0.0019037589615423873, 'gamma': 345.3423772587514}. Best is trial 0 with value: 0.6.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:37:03,450] Trial 51 finished with value: 0.6 and parameters: {'C': 0.06778384356265649, 'gamma': 97.94077584059272}. Best is trial 0 with value: 0.6.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# ...
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:38:35,216] Trial 82 finished with value: 0.6 and parameters: {'C': 0.00010133218247843102, 'gamma': 67.470682433334}. Best is trial 0 with value: 0.6.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:38:38,366] Trial 83 finished with value: 0.6 and parameters: {'C': 0.004222889796328346, 'gamma': 0.6738132686170624}. Best is trial 0 with value: 0.6.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:38:41,652] Trial 84 finished with value: 0.6 and parameters: {'C': 0.0014877570435593707, 'gamma': 196.5178378297414}. Best is trial 0 with value: 0.6.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:38:44,772] Trial 85 finished with value: 0.6 and parameters: {'C': 0.2244828645593509, 'gamma': 3.990163822603733}. Best is trial 0 with value: 0.6.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:38:47,251] Trial 86 finished with value: 0.6 and parameters: {'C': 0.0006661784562866802, 'gamma': 2119.721670651274}. Best is trial 0 with value: 0.6.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:38:50,419] Trial 87 finished with value: 0.6 and parameters: {'C': 0.002380112325498673, 'gamma': 1.4788164354220663}. Best is trial 0 with value: 0.6.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:38:53,591] Trial 88 finished with value: 0.6 and parameters: {'C': 0.0011045694276241034, 'gamma': 37.356621152835565}. Best is trial 0 with value: 0.6.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:38:56,097] Trial 89 finished with value: 0.6 and parameters: {'C': 0.000428645325149194, 'gamma': 14.683555569803787}. Best is trial 0 with value: 0.6.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:38:59,296] Trial 90 finished with value: 0.6 and parameters: {'C': 0.009549213949523981, 'gamma': 880.8506707612557}. Best is trial 0 with value: 0.6.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:39:02,439] Trial 91 finished with value: 0.6 and parameters: {'C': 1738.7009474815022, 'gamma': 8.87646470443167}. Best is trial 0 with value: 0.6.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:39:05,552] Trial 92 finished with value: 0.6 and parameters: {'C': 5311.055019137895, 'gamma': 3.4698755121997356}. Best is trial 0 with value: 0.6.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:39:08,646] Trial 93 finished with value: 0.6 and parameters: {'C': 3772.565947582395, 'gamma': 4.924399655036592}. Best is trial 0 with value: 0.6.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:39:11,704] Trial 94 finished with value: 0.6 and parameters: {'C': 8925.655992487724, 'gamma': 1.7734877162266374}. Best is trial 0 with value: 0.6.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:39:14,288] Trial 95 finished with value: 0.6 and parameters: {'C': 0.00027240166853645674, 'gamma': 2.3745492593035133}. Best is trial 0 with value: 0.6.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:39:17,437] Trial 96 finished with value: 0.6 and parameters: {'C': 400.7519487305451, 'gamma': 6452.831335379528}. Best is trial 0 with value: 0.6.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:39:20,570] Trial 97 finished with value: 0.6 and parameters: {'C': 0.017118303464602972, 'gamma': 2851.227084733747}. Best is trial 0 with value: 0.6.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:39:23,085] Trial 98 finished with value: 0.6 and parameters: {'C': 0.00014008260152305682, 'gamma': 0.975901755972311}. Best is trial 0 with value: 0.6.
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_34464\3528536040.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 20:39:26,213] Trial 99 finished with value: 0.6 and parameters: {'C': 0.005395639939176579, 'gamma': 450.53165406631985}. Best is trial 0 with value: 0.6.
# Best parameters for SVC:  {'C': 0.0019264458060227832, 'gamma': 1.0929230275330446}

# %%
# X_all_progression # y_progression

# %% [markdown]
# #### SVM (RADIAL) CROSS VALIDATION FOR All FEATURES

# %%
from sklearn.svm import SVC
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score, roc_curve, roc_auc_score, precision_recall_curve, average_precision_score, confusion_matrix
from sklearn.model_selection import StratifiedKFold
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Create a SVM classifier
# Specify hyperparameters
# C_value = 0.0019264458060227832
# gamma_value = 1.0929230275330446

# Create a SVM classifier
clf = SVC(**best_params, random_state=42, probability=True)

# Define the number of folds for cross-validation
n_splits = 3

# Initialize lists to store metrics for each fold
accuracies = []
precisions = []
recalls = []
f1_scores = []
roc_aucs = []
pr_aucs = []

# Initialize variables for mean ROC-AUC and PR-AUC
mean_roc_auc = 0
mean_pr_auc = 0

# Initialize lists to store ROC and PR curves for each fold
roc_curves = []

# Initialize lists to store recall and precision values for each fold
recall_values = []
precision_values = []

# Initialize the list to store confusion matrices for each fold
confusion_matrices = []

# Define your binary class labels
class_labels = y_progression.unique()

# Create a StratifiedKFold object for cross-validation
skf = StratifiedKFold(n_splits=n_splits)

for train_index, test_index in skf.split(X_all_progression.values, y_progression):
    X_train, X_test = X_all_progression.iloc[train_index], X_all_progression.iloc[test_index]
    y_train, y_test = y_progression[train_index], y_progression[test_index]

    # Train the Random Forest classifier
    clf.fit(X_train, y_train)

    # Make predictions on the test set
    y_pred_probs = clf.predict_proba(X_test)
    y_pred = np.argmax(y_pred_probs, axis=1)

    # Calculate accuracy, precision, recall, and F1-score
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred, average='binary')
    recall = recall_score(y_test, y_pred, average='binary')
    f1 = f1_score(y_test, y_pred, average='binary')

    # Store the metrics for this fold
    accuracies.append(accuracy)
    precisions.append(precision)
    recalls.append(recall)
    f1_scores.append(f1)

    # Calculate ROC-AUC for this fold
    fpr, tpr, _ = roc_curve(y_test, y_pred_probs[:, 1])
    roc_auc = roc_auc_score(y_test, y_pred_probs[:, 1])
    roc_aucs.append(roc_auc)
    roc_curves.append((fpr, tpr))

    # Calculate and append the confusion matrix for this fold
    conf_matrix = confusion_matrix(y_test, y_pred)
    confusion_matrices.append(conf_matrix)

    # Calculate Precision-Recall values for this fold
    precision_fold, recall_fold, _ = precision_recall_curve(y_test, y_pred_probs[:, 1])
    recall_values.append(recall_fold)
    precision_values.append(precision_fold)

    # Calculate PR-AUC for this fold
    pr_auc = average_precision_score(y_test, y_pred_probs[:, 1])
    pr_aucs.append(pr_auc)

    # Update mean ROC-AUC and PR-AUC
    mean_roc_auc += roc_auc
    mean_pr_auc += pr_auc

# Calculate mean ROC-AUC and PR-AUC across folds
mean_roc_auc /= n_splits
mean_pr_auc /= n_splits

# Print the confusion matrices for each fold
for i, conf_matrix in enumerate(confusion_matrices):
    confusion_matrix_df = pd.DataFrame(conf_matrix, index=class_labels, columns=class_labels)
    print(f"Confusion Matrix for Fold {i} with Progression:")
    print(confusion_matrix_df)

# Print the mean metrics across folds
print("Mean Accuracy:", np.mean(accuracies))
print("Mean Precision:", np.mean(precisions))
print("Mean Recall:", np.mean(recalls))
print("Mean F1-score:", np.mean(f1_scores))
print("Mean ROC-AUC:", mean_roc_auc)
print("Mean PR-AUC:", mean_pr_auc)

# Plot the ROC curve for each fold and the mean ROC-AUC
plt.figure(figsize=(8, 6))
for i, (fpr, tpr) in enumerate(roc_curves):
    roc_auc = roc_aucs[i]
    plt.plot(fpr, tpr, label=f'Fold {i} (AUC = {roc_auc:.2f})')

plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve (5-Fold Cross-Validation)')
plt.legend(loc='best')
plt.grid()
plt.show()

# Plot the Precision-Recall curves for each fold
plt.figure(figsize=(8, 6))
for i, (recall, precision) in enumerate(zip(recall_values, precision_values)):
    pr_auc = pr_aucs[i]
    plt.plot(recall, precision, label=f'Fold {i} (AUC = {pr_auc:.2f})')

plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curves (5-Fold Cross-Validation)')
plt.legend(loc='best')
plt.grid()
plt.show()
# Out:
# C:\Users\isile\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\isile\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Confusion Matrix for Fold 0 with Progression:
#     1  0
# 1  61  0
# 0  39  0
# Confusion Matrix for Fold 1 with Progression:
#     1  0
# 1  60  0
# 0  39  0
# Confusion Matrix for Fold 2 with Progression:
#     1  0
# 1  60  0
# 0  39  0
# Mean Accuracy: 0.6073737373737375
# Mean Precision: 0.0
# Mean Recall: 0.0
# Mean F1-score: 0.0
# Mean ROC-AUC: 0.5
# Mean PR-AUC: 0.3926262626262626
# C:\Users\isile\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# #### LOGISTIC REGRESSION HYPERPARAMETER TUNING FOR ALL FEATURES

# %%
##############FOR LOGISTIC REGRESSION-HYPER PARAMETER TUNING #########################
from sklearn.linear_model import LogisticRegression
# Set the parameters for random search (for logistic regression)
param_grid = {
    'C': np.logspace(-4, 4, 20),#this search is really large space
    'penalty': ['l1'], #l1 loss
    'solver': ['liblinear']
}

# Initialize a LogisticRegression (define the Logistic regression classifier)
lr = LogisticRegression(random_state=42)

# Initialize Grid_SearchCV (define the random search algorithm#this time we want to use Random serach because we dont want to search the all the combinations)
grid_search = GridSearchCV(estimator=lr, param_grid=param_grid, cv=5)

# Fit Grid_SearchCV
grid_search.fit(X_all_progression, y_progression)

#after that we  obtain the best parameters from the random search

# Get the best parameters
best_params = grid_search.best_params_
print('Best parameters for LogisticRegression: ', best_params)
# Out:
# Best parameters for LogisticRegression:  {'C': 29.763514416313132, 'penalty': 'l1', 'solver': 'liblinear'}

# %%
# X_all_progression # y_progression

# %% [markdown]
# #### LOGISTIC REGRESSION CROSS VALIDATION FOR ALL FEATURES

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score, roc_curve, roc_auc_score, precision_recall_curve, average_precision_score, confusion_matrix
from sklearn.model_selection import StratifiedKFold
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Create a Random Forest classifier
clf = LogisticRegression(**best_params, random_state=42)

# Define the number of folds for cross-validation
n_splits = 3

# Initialize lists to store metrics for each fold
accuracies = []
precisions = []
recalls = []
f1_scores = []
roc_aucs = []
pr_aucs = []

# Initialize variables for mean ROC-AUC and PR-AUC
mean_roc_auc = 0
mean_pr_auc = 0

# Initialize lists to store ROC and PR curves for each fold
roc_curves = []

# Initialize lists to store recall and precision values for each fold
recall_values = []
precision_values = []

# Initialize the list to store confusion matrices for each fold
confusion_matrices = []

# Define your binary class labels
class_labels = y_progression.unique()

# Create a StratifiedKFold object for cross-validation
skf = StratifiedKFold(n_splits=n_splits)

for train_index, test_index in skf.split(X_all_progression.values, y_progression):
    X_train, X_test = X_all_progression.iloc[train_index], X_all_progression.iloc[test_index]
    y_train, y_test = y_progression[train_index], y_progression[test_index]

    # Train the Random Forest classifier
    clf.fit(X_train, y_train)

    # Make predictions on the test set
    y_pred_probs = clf.predict_proba(X_test)
    y_pred = np.argmax(y_pred_probs, axis=1)

    # Calculate accuracy, precision, recall, and F1-score
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred, average='binary')
    recall = recall_score(y_test, y_pred, average='binary')
    f1 = f1_score(y_test, y_pred, average='binary')

    # Store the metrics for this fold
    accuracies.append(accuracy)
    precisions.append(precision)
    recalls.append(recall)
    f1_scores.append(f1)

    # Calculate ROC-AUC for this fold
    fpr, tpr, _ = roc_curve(y_test, y_pred_probs[:, 1])
    roc_auc = roc_auc_score(y_test, y_pred_probs[:, 1])
    roc_aucs.append(roc_auc)
    roc_curves.append((fpr, tpr))

    # Calculate and append the confusion matrix for this fold
    conf_matrix = confusion_matrix(y_test, y_pred)
    confusion_matrices.append(conf_matrix)

    # Calculate Precision-Recall values for this fold
    precision_fold, recall_fold, _ = precision_recall_curve(y_test, y_pred_probs[:, 1])
    recall_values.append(recall_fold)
    precision_values.append(precision_fold)

    # Calculate PR-AUC for this fold
    pr_auc = average_precision_score(y_test, y_pred_probs[:, 1])
    pr_aucs.append(pr_auc)

    # Update mean ROC-AUC and PR-AUC
    mean_roc_auc += roc_auc
    mean_pr_auc += pr_auc

# Calculate mean ROC-AUC and PR-AUC across folds
mean_roc_auc /= n_splits
mean_pr_auc /= n_splits

# Print the confusion matrices for each fold
for i, conf_matrix in enumerate(confusion_matrices):
    confusion_matrix_df = pd.DataFrame(conf_matrix, index=class_labels, columns=class_labels)
    print(f"Confusion Matrix for Fold {i} with Progression:")
    print(confusion_matrix_df)

# Print the mean metrics across folds
print("Mean Accuracy:", np.mean(accuracies))
print("Mean Precision:", np.mean(precisions))
print("Mean Recall:", np.mean(recalls))
print("Mean F1-score:", np.mean(f1_scores))
print("Mean ROC-AUC:", mean_roc_auc)
print("Mean PR-AUC:", mean_pr_auc)

# Plot the ROC curve for each fold and the mean ROC-AUC
plt.figure(figsize=(8, 6))
for i, (fpr, tpr) in enumerate(roc_curves):
    roc_auc = roc_aucs[i]
    plt.plot(fpr, tpr, label=f'Fold {i} (AUC = {roc_auc:.2f})')

plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve (5-Fold Cross-Validation)')
plt.legend(loc='best')
plt.grid()
plt.show()

# Plot the Precision-Recall curves for each fold
plt.figure(figsize=(8, 6))
for i, (recall, precision) in enumerate(zip(recall_values, precision_values)):
    pr_auc = pr_aucs[i]
    plt.plot(recall, precision, label=f'Fold {i} (AUC = {pr_auc:.2f})')

plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curves (5-Fold Cross-Validation)')
plt.legend(loc='best')
plt.grid()
plt.show()
# Out:
# Confusion Matrix for Fold 0 with Progression:
#     1   0
# 1  46  15
# 0   7  32
# Confusion Matrix for Fold 1 with Progression:
#     1   0
# 1  43  17
# 0   8  31
# Confusion Matrix for Fold 2 with Progression:
#     1   0
# 1  43  17
# 0  11  28
# Mean Accuracy: 0.7482154882154882
# Mean Precision: 0.6496355397951142
# Mean Recall: 0.7777777777777778
# Mean F1-score: 0.7078321304464046
# Mean ROC-AUC: 0.8427794124515436
# Mean PR-AUC: 0.7641793689612357
