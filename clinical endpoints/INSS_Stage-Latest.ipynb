# %% [markdown]
# #### Feature selection for INSS. Stage

# %%
#Load the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import metrics
from sklearn.preprocessing import LabelEncoder

# %%
#En son veriler
X_train=pd.read_csv("X_train.csv", index_col="ID")
X_test=pd.read_csv("X_test.csv", index_col="ID")
y_train=pd.read_csv("y_train.csv", index_col="ID")
y_test=pd.read_csv("y_test.csv", index_col="ID")

# %%
y_train["INSS.Stage"].value_counts()
# Out:
# INSS.Stage
# 4     151
# 1      96
# 4S     39
# 3       9
# 2       3
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
# #only get one target
y_inss=y_train["INSS.Stage"]

# Initialize the LabelEncoder
label_encoder = LabelEncoder()

# Fit and transform the class labels to numeric values
y_inss_encode = label_encoder.fit_transform(y_inss)

# Now, if you want to get the original labels from the encoded values:
original_labels = label_encoder.inverse_transform(y_inss_encode)

# %%
original_labels
# Out:
# array(['4', '4S', '1', '4', '4', '4', '1', '1', '1', '4S', '4', '4', '1',
#        '4', '1', '4', '1', '4', '4', '4', '4', '4', '4S', '1', '4S', '1',
#        '4', '1', '4', '4', '4S', '4', '4', '4', '4S', '1', '4', '4', '4',
#        '1', '3', '1', '1', '4', '4', '4', '4', '1', '1', '4', '1', '4',
#        '3', '4', '1', '3', '4', '1', '4', '4', '1', '4', '4S', '1', '1',
#        '4S', '1', '1', '4', '4', '4S', '1', '4', '4', '4', '4', '4S', '1',
#        '1', '3', '4', '4', '1', '4', '1', '4', '4', '2', '1', '4S', '4S',
#        '2', '3', '4', '4S', '4', '4', '4', '4S', '4', '1', '4', '4', '4S',
#        '1', '1', '4', '4', '1', '1', '4', '4', '4', '1', '4', '4S', '4',
#        '1', '4', '1', '3', '1', '4', '4', '4', '4', '4', '4S', '3', '4S',
#        '4', '1', '4S', '4', '1', '1', '1', '4', '1', '4', '4S', '4', '4',
#        '1', '4', '4S', '4S', '4S', '4', '1', '1', '4', '4', '4', '4', '4',
#        '1', '1', '4', '4', '4', '1', '4', '4', '4', '4', '4S', '1', '1',
#        '4', '4', '4', '4', '4', '1', '1', '4S', '4', '1', '4', '4', '4S',
#        '4S', '4S', '4S', '1', '4', '4', '4', '1', '1', '4S', '4', '4',
#        '4S', '4', '1', '4', '1', '4', '4', '4', '4', '1', '4', '1', '4',
#        '1', '4S', '1', '4', '1', '4', '4', '4', '4', '4', '4', '4', '4S',
#        '4', '4', '4S', '1', '1', '4', '1', '1', '4', '4', '4', '4', '4',
#        '4', '1', '4', '4S', '1', '4S', '4', '4', '1', '4', '4', '4', '1',
#        '4', '1', '1', '4', '3', '4', '1', '1', '1', '4S', '2', '4', '4',
#        '4', '1', '1', '1', '1', '1', '4', '1', '4', '4', '4', '1', '4',
#        '4', '3', '4', '4', '4', '1', '1', '4', '4', '1', '1', '1', '4',
#        '4S', '4', '1', '1', '1', '4', '4', '4', '4S', '4', '1', '1', '1'],
#       dtype=object)

# %%
# #INSS is associated with INSS therefore don't put this in feature matrix
# excluded_features = ["clinico.genetic.subgroup_MNA","clinico.genetic.subgroup_ST1","clinico.genetic.subgroup_ST4", "clinico.genetic.subgroup_ST4S"]
# X=X_train.loc[:, ~X_train.columns.isin(excluded_features)]
# y=y_inss_encode.copy()

# %% [markdown]
# #### Random Forest Feature selection

# %%
# # Import necessary libraries
# from sklearn.model_selection import StratifiedKFold, GridSearchCV
# from sklearn.ensemble import RandomForestClassifier
# import matplotlib.pyplot as plt
# import seaborn as sns
# import pandas as pd
# from sklearn.feature_selection import SelectKBest, chi2, f_classif, mutual_info_classif, SelectPercentile
# from sklearn.model_selection import KFold, StratifiedKFold, StratifiedGroupKFold
# from sklearn.metrics import accuracy_score, f1_score

# skf = StratifiedKFold(n_splits=5)

# rf = RandomForestClassifier()

# # Initialize lists to store accuracy and F1 scores for each fold
# accuracy_scores = []
# f1_scores = []

# ## Number of top features
# top_k = 300

# # Initialize list to hold common features from each fold
# common_features = []

# # Iterate over each split
# # Iterate over each split
# for train_index, test_index in skf.split(X, y):
#     X_train_temp, X_test_temp = X.iloc[train_index], X.iloc[test_index]  
#     y_train_temp, y_test_temp = y[train_index], y[test_index]

#     # Initialize feature selectors
#     selector_kbest = SelectKBest(score_func=f_classif, k=top_k)  # Adjust 'k' as per your requirements
#     selector_percentile = SelectPercentile(score_func=f_classif, percentile=1)
    
#     # Fit and transforX_train, y_trainm the data
#     X_new_kbest = selector_kbest.fit_transform(X_train_temp, y_train_temp)
#     X_new_percentile = selector_percentile.fit_transform(X_train_temp, y_train_temp)
    
#     # Get the selected features
#     selected_features_kbest = X_train_temp.columns[selector_kbest.get_support()]
#     selected_features_percentile = X_train_temp.columns[selector_percentile.get_support()]
    
#     # Get the common features and add to the list
#     common_features_fold = set(selected_features_kbest) & set(selected_features_percentile)
#     common_features.append(common_features_fold)
#     #print("Common Features in thi Fold : ", common_features_fold )

#     # Train the model on the selected features and compute the accuracy
#     X_train_selected = X_train_temp[list(common_features_fold)]
#     X_test_selected = X_test_temp[list(common_features_fold)]
#     rf.fit(X_train_selected, y_train_temp)
#     y_pred = rf.predict(X_test_selected)

#      # Calculate accuracy
#     accuracy = accuracy_score(y_test_temp, y_pred)
    
#     # Calculate F1 score
#     f1 = f1_score(y_test_temp, y_pred, average="weighted")

#     print(f'Accuracy for this fold: {accuracy}')
#     print(f'F1 score for this fold: {f1}')

#     # Append scores to the lists
#     accuracy_scores.append(accuracy)
#     f1_scores.append(f1)

# # Calculate the mean accuracy and F1 score
# mean_accuracy = sum(accuracy_scores) / len(accuracy_scores)
# mean_f1_score = sum(f1_scores) / len(f1_scores)

# print(f'Mean Accuracy: {mean_accuracy}')
# print(f'Mean F1 Score: {mean_f1_score}')


# # Get the intersection of common features from all folds
# final_common_features = set.intersection(*map(set, common_features))

# print(f"Final common features: {final_common_features}")
# Out:
# c:\Users\isile\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_split.py:737: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# Accuracy for this fold: 0.7333333333333333
# F1 score for this fold: 0.6958333333333332
# Accuracy for this fold: 0.7833333333333333
# F1 score for this fold: 0.7045102184637069
# Accuracy for this fold: 0.7333333333333333
# F1 score for this fold: 0.692910447761194
# Accuracy for this fold: 0.7627118644067796
# F1 score for this fold: 0.7181994998610725
# Accuracy for this fold: 0.711864406779661
# F1 score for this fold: 0.6751779294152175
# Mean Accuracy: 0.7449152542372881
# Mean F1 Score: 0.6973262857669048
# Final common features: {'Unnamed: 10293', 'Unnamed: 27244', 'Unnamed: 23848', 'Unnamed: 9100', 'Unnamed: 12780', 'Unnamed: 20557', 'Unnamed: 3572', 'Unnamed: 36445', 'Unnamed: 20215', 'Unnamed: 10440', 'Unnamed: 21866', 'YPEL1', 'Unnamed: 11471', 'Unnamed: 7357', 'Unnamed: 40711', 'Unnamed: 41668', 'PDLIM5', 'PNPLA5', 'Unnamed: 21800', 'Unnamed: 39693', 'Unnamed: 32028', 'Unnamed: 3564', 'Unnamed: 19017', 'Unnamed: 10992', 'Unnamed: 8198', 'Unnamed: 27503', 'Unnamed: 9105', 'GPNMB.1', 'Unnamed: 28860', 'Unnamed: 30620', 'RFX6', 'Unnamed: 8511', 'Unnamed: 3561', 'Unnamed: 3237', 'Unnamed: 35690', 'ALKBH1', 'PRKACA', 'Unnamed: 19634', 'Unnamed: 37667', 'Unnamed: 445', 'Unnamed: 9951', 'Unnamed: 24621', 'Unnamed: 38288', 'EID3', 'Unnamed: 19026', 'Unnamed: 41569', 'Unnamed: 41369', 'Unnamed: 2163', 'Unnamed: 36026', 'Unnamed: 47', 'Unnamed: 9829', 'Unnamed: 13566', 'Unnamed: 40813', 'Unnamed: 5824', 'Unnamed: 9273', 'Unnamed: 8332', 'Unnamed: 27587', 'Unnamed: 34510', 'SLC5A4-AS1|CPSF1', 'Unnamed: 6824', 'Unnamed: 12923', 'Unnamed: 18278', 'AK7', 'Unnamed: 30576', 'ADAMTS5', 'GABRR3', 'Unnamed: 1907', 'DOLK', 'Unnamed: 2074', 'Unnamed: 22367', 'Unnamed: 13211', 'Unnamed: 40183', 'Unnamed: 44457', 'Unnamed: 30461', 'Unnamed: 21078', 'Unnamed: 27889', 'Unnamed: 22174', 'Unnamed: 32814', 'DDB1', 'Unnamed: 25764', 'Unnamed: 24941', 'CNN3', 'Unnamed: 8312', 'Unnamed: 44185', 'Unnamed: 33817', 'Unnamed: 29982', 'Unnamed: 5407', 'Unnamed: 25570', 'Unnamed: 38436', 'Unnamed: 5713', 'Unnamed: 12741', 'PTPN11.5', 'BCDIN3D', 'ARRDC3', 'Unnamed: 23401', 'Unnamed: 14111', 'Unnamed: 378', 'TNPO3', 'BLNK', 'Unnamed: 1317', 'Unnamed: 27200', 'TUBA1A', 'LRTOMT|NUMA1', 'Unnamed: 26480', 'Unnamed: 10275', 'Unnamed: 31813', 'Unnamed: 24408', 'Unnamed: 4714', 'CFAP43', 'Unnamed: 5682', 'Unnamed: 26332', 'Unnamed: 31317', 'ALDH3A1.1', 'Unnamed: 43450', 'Unnamed: 11034', 'EIF3F', 'STX7', 'Unnamed: 42147', 'Unnamed: 4171', 'WDR59', 'Unnamed: 39533', 'Unnamed: 23410', 'TALDO1', 'Unnamed: 36115', 'Unnamed: 15364', 'KRTAP7-1', 'ARL6IP5', 'Unnamed: 7415', 'E2F3', 'MTMR9LP', 'TBC1D5', 'Unnamed: 33328', 'Unnamed: 582', 'Unnamed: 44058', 'Unnamed: 16192', 'Unnamed: 25946', 'Unnamed: 17674', 'Unnamed: 4501', 'Unnamed: 2062', 'Unnamed: 6253', 'Unnamed: 31728', 'Unnamed: 18618', 'ESR1.2'}

# %%
# # Convert the set to a DataFrame
# final_common_features_df = pd.DataFrame(final_common_features, columns=["FeatureName"])

# # Save it to a CSV file
# final_common_features_df.to_csv("final_common_features_for_INSS.csv", index=False)

# %%
# final_common_features_df

# %% [markdown]
# After feature selection none of the clinical features were selected. I maybe try to use some of them but taking care of oversampling or outliers
# Be careful about clinico genetic subgroup for INSS, We cannot use it due to redundancy.

# %% [markdown]
# COMMON SELECTED FEATURES AMONG CLINICAL ENDPOINTS

# %%
# import csv
# selected_features_inss = pd.read_csv("final_common_features_for_INSS.csv",index_col=False)
# selected_features_hr = pd.read_csv("final_common_features_for_HighRisk.csv",index_col=False)
# selected_features_prog = pd.read_csv("final_common_features_for_Progression.csv",index_col=False)
# selected_features_death = pd.read_csv("final_common_features_for_DeathFromDisease.csv",index_col=False)

# feature_dataframes=[selected_features_inss,selected_features_hr,selected_features_prog,selected_features_death]
# # Initialize a list to store the common features for all pairs
# common_features_list = []

# # Compare each pair of dataframes using nested loops
# for i in range(len(feature_dataframes)):
#     for j in range(i + 1, len(feature_dataframes)):
#         df1 = feature_dataframes[i]
#         df2 = feature_dataframes[j]

#         # Find common features between the current pair of dataframes
#         common_features = set(df1["FeatureName"]).intersection(df2["FeatureName"])

#         # Append the common features to the list
#         common_features_list.append([f"Dataframes {i+1} and {j+1}", ",".join(common_features)])

# # Save the common features list to a CSV file
# with open("common_selected_features_list.csv", "w", newline="") as csvfile:
#     csv_writer = csv.writer(csvfile)
#     csv_writer.writerow(["Pair", "Common Features"])
#     csv_writer.writerows(common_features_list)

# %% [markdown]
# ####  RANDOM FOREST FEATURE IMPORTANCE

# %%
# from sklearn.ensemble import RandomForestClassifier
# from sklearn.model_selection import StratifiedKFold
# import matplotlib.pyplot as plt
# import numpy as np

# # Initialize a Random Forest Classifier
# rfc = RandomForestClassifier(random_state=42)

# # Initialize lists to store feature importances for each fold
# feature_importances = []

# # Initialize StratifiedKFold
# skf = StratifiedKFold(n_splits=5)

# # Iterate over each split
# for train_index, test_index in skf.split(X, y):
#     X_train_temp, X_test_temp = X.iloc[train_index], X.iloc[test_index]
#     y_train_temp, y_test_temp = y[train_index], y[test_index]

#     # Fit the Random Forest Classifier
#     rfc.fit(X_train_temp, y_train_temp)

#     # Get feature importances from the trained model
#     importances = rfc.feature_importances_
#     feature_importances.append(importances)

# # Calculate the mean feature importances across all folds
# mean_feature_importances = np.mean(feature_importances, axis=0)

# # Sort the common features by their corresponding importances in descending order
# sorted_common_features = [X.columns[feature] for feature in sorted(common_features, key=lambda x: mean_feature_importances[x], reverse=False)]

# # Select the top N common features (e.g., top 100 features)
# num_top_features = 100
# top_common_features = sorted_common_features[:num_top_features]

# # Plot the top common feature importances in a horizontal bar chart
# plt.figure(figsize=(10, 6))
# plt.barh(range(len(top_common_features)), [mean_feature_importances[X.columns.get_loc(feature)] for feature in top_common_features], align="center", color="darkolivegreen")
# plt.yticks(range(len(top_common_features)), top_common_features)
# plt.xlabel("Mean Feature Importance")
# plt.ylabel("Feature")
# plt.title("Top Common Feature Importances for INSS.Stage")
# plt.show()
# Out:
# c:\Users\isile\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_split.py:737: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(

# %% [markdown]
# ### Hyperparameter tuning and Cross Validation

# %% [markdown]
# Stratified Cross-Validation on X_train for multiclass INSS.Stage clinical endpoint, after hyperparameter tuning (cv=3) because stage2 has only 3 samples
#
# Conducting a 3-fold cross-validation on the training dataset after hyperparameter tuning is a prudent approach in machine learning. This practice allows to evaluate the model's generalization performance within the training dataset without risking data leakage from the reserved test data. In addition CV provides a valuable assessment of how well your model performs across different subsets of the training data and seeing the anomalies on the data which offering a reasonable estimate of its potential performance on unseen data. Moreover, comparing the cross-validation results to the initial single random split helps me estimate the consistency of your model's performance and builds confidence in the reliability of that single split. In otherwords, I have performed the train and test split from original data and I have one split for trainset only but in order to understand how this split reflects the overall dataset, this approach is very valuable.

# %% [markdown]
# ##### Set the X and y

# %%
####X feature matrix
#### Import selected features for INSS
selected_features_inss = pd.read_csv("final_common_features_for_INSS.csv",index_col=False)
##
#### Put them in a list
selected_features = selected_features_inss['FeatureName'].tolist()

# Subset X_train to include only the selected features
X_sub_inss = X_train[selected_features]
X_sub_inss

# y y_inss_encode
# Out:
#             ESR1.2  Unnamed: 9273      DOLK   MTMR9LP      E2F3  \
# ID
# ICGC_466  0.088675       0.374905 -0.353182  0.493617  0.412768
# ICGC_292  0.401301      -0.714407 -0.128004  0.187416  0.336705
# ICGC_032  0.771515       0.717610  0.889800  0.921143  0.510564
# ICGC_408  0.713926      -1.791480 -0.605381 -0.580976 -1.309519
# ICGC_108  0.787969      -0.261547  0.457458  0.210525  0.548595
# ...            ...            ...       ...       ...       ...
# ICGC_309  0.376620       0.044440  0.142210  0.770931  1.162534
# ICGC_371 -1.194736      -0.102434  0.133202  0.510949 -0.646683
# ICGC_107  1.380313       1.329584  0.736679  1.417998  0.347571
# ICGC_344  0.779742       0.729850  0.898807  0.187416  1.504818
# ICGC_053  0.977190       0.105637  0.394409  0.557168  0.733320
#
#           Unnamed: 25946  Unnamed: 7357  Unnamed: 41369  Unnamed: 8332  \
# ID
# ICGC_466        0.067744       0.450173       -0.466201      -1.310932
# ICGC_292        0.419965      -0.235063        0.220557       1.097063
# ICGC_032        0.381366       0.840685        0.841910       0.971476
# ICGC_408       -0.853822      -2.187620       -0.963283      -0.000458
# ICGC_108       -0.168679       0.125975        0.377530       0.774905
# ...                  ...            ...             ...            ...
# ICGC_309        0.458565       0.192289        0.626072       0.742144
# ICGC_371       -0.458176      -0.154014       -0.695121       0.359922
# ICGC_107        0.960360       1.489081        0.220557       0.220684
# ICGC_344        1.076159       0.914366        1.005424       0.220684
# ICGC_053        1.703403       0.708058        0.645693       0.507350
#
#           SLC5A4-AS1|CPSF1  ...  Unnamed: 10293  Unnamed: 378  Unnamed: 17674  \
# ID                          ...
# ICGC_466          0.461749  ...       -0.268176     -0.520172        0.947308
# ICGC_292          0.135441  ...        0.110909     -0.635048       -0.635356
# ICGC_032          0.628788  ...        0.507627      0.566727        1.145140
# ICGC_408         -2.393452  ...       -1.669913      0.010023       -0.566114
# ICGC_108          0.341326  ...        0.401836     -0.219728        0.027385
# ...                    ...  ...             ...           ...             ...
# ICGC_309          0.850212  ...        0.172621      0.151408        0.403267
# ICGC_371         -0.256907  ...        0.534075      0.098389       -0.210015
# ICGC_107          1.032789  ...        0.842633      1.132268        1.026441
# ICGC_344          0.714250  ...        0.736842      1.158778        0.521967
# ICGC_053          0.325787  ...        1.001320      0.186754       -0.427631
#
#           Unnamed: 10275  Unnamed: 18278  Unnamed: 3564  Unnamed: 19017  \
# ID
# ICGC_466        0.236972        0.772771      -1.821835        0.149382
# ICGC_292       -0.005921       -0.272603       0.225096        0.350147
# ICGC_032        0.579881        0.081475      -0.062990        0.114634
# ICGC_408       -0.477421       -0.373768      -0.745301       -0.468357
# ICGC_108        0.165533       -0.120855       0.308490        0.929277
# ...                  ...             ...            ...             ...
# ICGC_309        0.286980        0.115197       0.482858        0.365590
# ICGC_371        0.658464        0.266945      -0.396564        0.114634
# ICGC_107        0.422715        0.789632       1.438093        0.373312
# ICGC_344        0.858494        0.283806       1.195493        0.890668
# ICGC_053        0.236972        0.064614       1.695855        0.041278
#
#           Unnamed: 11034  Unnamed: 5682  Unnamed: 28860
# ID
# ICGC_466        1.134327      -0.288519        0.349698
# ICGC_292        0.050565      -0.656489       -0.298251
# ICGC_032        0.392501       0.116247        1.039450
# ICGC_408       -0.140687      -2.096827       -1.338104
# ICGC_108       -0.256598       0.804876        0.307895
# ...                  ...            ...             ...
# ICGC_309        1.285010       0.142531        0.485558
# ICGC_371        0.050565      -0.299033       -0.549070
# ICGC_107        1.087963       1.698516        0.318346
# ICGC_344        1.296601       0.973091        0.464657
# ICGC_053        0.183862       0.100477        1.002872
#
# [298 rows x 143 columns]

# %% [markdown]
# #### RANDOM FOREST HYPERPARAMETER TUNING FOR SELECTED FEATURES

# %%
#Import necessary libraries
from sklearn.model_selection import  GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, roc_curve, auc, precision_recall_curve, average_precision_score

##############FOR RANDOM FOREST-HYPER PARAMETER TUNING#########################

# Set the parameters for grid search (for Random Forest) #we can give choices inside in list as much as we want
param_grid = {
    'n_estimators': [100, 200, 300], 
    'max_depth': [3, 5, 7],
    'min_samples_split': [2, 5, 10]#choices 2,5 and 10
}

# Initialize a RandomForestClassifier (define the Random Forest classifier)
rf = RandomForestClassifier(random_state=42)

# Initialize GridSearchCV (define the grid search algorithm)
grid_search = GridSearchCV(estimator=rf, param_grid=param_grid, cv=5) #here in param_grid ,we provide the param_grid that we set above

# Fit GridSearchCV
grid_search.fit(X_sub_inss, y_inss_encode)
#during grid search for train set, every possible combinations of the parameter choices that we set above will be tested.
#And for ever single parameter combination, it will run cross_validation for 5 folds

#after that we obtain the best parameters from the grid search

# Get the best parameters (for the random forest)
best_params = grid_search.best_params_
print('Best parameters for RandomForestClassifier: ', best_params)
# Out:
# Best parameters for RandomForestClassifier:  {'max_depth': 7, 'min_samples_split': 2, 'n_estimators': 300}

# %% [markdown]
# #### RANDOM FOREST CROSS VALIDATION FOR SELECTED FEATURES

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score, roc_curve, roc_auc_score, precision_recall_curve, average_precision_score,confusion_matrix
from sklearn.model_selection import StratifiedKFold
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Create a Random Forest classifier
clf = RandomForestClassifier(**best_params, random_state=42)

# Define the number of folds for cross-validation
n_splits = 3

# Initialize lists to store metrics for each fold
accuracies = []
precisions = []
recalls = []
f1_scores = []
roc_aucs = []
pr_aucs = []

# Initialize variables for mean ROC-AUC and PR-AUC
mean_roc_auc = 0
mean_pr_auc = 0

# Initialize lists to store ROC and PR curves for each fold
roc_curves = []

# Initialize lists to store recall and precision values for each fold
recall_values = []
precision_values = []

# Initialize the list to store confusion matrices for each fold
confusion_matrices = []

# Create a StratifiedKFold object for cross-validation
skf = StratifiedKFold(n_splits=n_splits)

for train_index, test_index in skf.split(X_sub_inss.values, y_inss_encode):
    X_train, X_test = X_sub_inss.iloc[train_index], X_sub_inss.iloc[test_index]
    y_train, y_test = y_inss_encode[train_index], y_inss_encode[test_index]

    # Train the Random Forest classifier
    clf.fit(X_train, y_train)

    # Make predictions on the test set
    y_pred_probs = clf.predict_proba(X_test)
    y_pred = np.argmax(y_pred_probs, axis=1)

    # Calculate accuracy, precision, recall, and F1-score
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred, average='micro')
    recall = recall_score(y_test, y_pred, average='micro')
    f1 = f1_score(y_test, y_pred, average='micro')

    # Store the metrics for this fold
    accuracies.append(accuracy)
    precisions.append(precision)
    recalls.append(recall)
    f1_scores.append(f1)

    # Calculate ROC-AUC for this fold
    y_true_binary = np.zeros_like(y_pred_probs)
    y_true_binary[np.arange(y_pred_probs.shape[0]), y_test] = 1
    fpr, tpr, _ = roc_curve(y_true_binary.ravel(), y_pred_probs.ravel())
    roc_auc = roc_auc_score(y_true_binary.ravel(), y_pred_probs.ravel())
    roc_aucs.append(roc_auc)
    roc_curves.append((fpr, tpr))

    # Calculate and append the confusion matrix for this fold
    conf_matrix = confusion_matrix(y_test, y_pred)
    confusion_matrices.append(conf_matrix)


    # Calculate Precision-Recall values for this fold
    precision_fold, recall_fold, _ = precision_recall_curve(y_true_binary.ravel(), y_pred_probs.ravel())
    recall_values.append(recall_fold)
    precision_values.append(precision_fold)

    # Calculate PR-AUC for this fold
    pr_auc = average_precision_score(y_true_binary.ravel(), y_pred_probs.ravel())
    pr_aucs.append(pr_auc)

    # Update mean ROC-AUC and PR-AUC
    mean_roc_auc += roc_auc
    mean_pr_auc += pr_auc

# Calculate mean ROC-AUC and PR-AUC across folds
mean_roc_auc /= n_splits
mean_pr_auc /= n_splits

# Obtain unique class labels from y_test_inss
class_labels = ['1', '2', '3', '4', '4S']

# Print the confusion matrices for each fold
for i, conf_matrix in enumerate(confusion_matrices):
    confusion_matrix_df = pd.DataFrame(conf_matrix, index=class_labels, columns=class_labels)
    print(f"Confusion Matrix for Fold {i} with INSS.Stages:")
    print(confusion_matrix_df)

# Print the mean metrics across folds
print("Mean Accuracy:", np.mean(accuracies))
print("Mean Precision:", np.mean(precisions))
print("Mean Recall:", np.mean(recalls))
print("Mean F1-score:", np.mean(f1_scores))
print("Mean ROC-AUC:", mean_roc_auc)
print("Mean PR-AUC:", mean_pr_auc)

# Plot the ROC curve for each fold and the mean ROC-AUC
plt.figure(figsize=(8, 6))
for i, (fpr, tpr) in enumerate(roc_curves):
    roc_auc = roc_aucs[i]
    plt.plot(fpr, tpr, label=f'Fold {i} (AUC = {roc_auc:.2f})')

plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Micro-Averaged ROC Curve (5-Fold Cross-Validation)')
plt.legend(loc='best')
plt.grid()
plt.show()

# Plot the Precision-Recall curves for each fold
plt.figure(figsize=(8, 6))
for i, (recall, precision) in enumerate(zip(recall_values, precision_values)):
    pr_auc = pr_aucs[i]
    plt.plot(recall, precision, label=f'Fold {i} (AUC = {pr_auc:.2f})')

plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Micro-Averaged Precision-Recall Curves (5-Fold Cross-Validation)')
plt.legend(loc='best')
plt.grid()
plt.show()
# Out:
# Confusion Matrix for Fold 0 with INSS.Stages:
#      1  2  3   4  4S
# 1   30  0  0   2   0
# 2    0  0  0   1   0
# 3    0  0  0   3   0
# 4    5  0  0  46   0
# 4S   7  0  0   5   1
# Confusion Matrix for Fold 1 with INSS.Stages:
#      1  2  3   4  4S
# 1   28  0  0   4   0
# 2    0  0  0   1   0
# 3    0  0  0   3   0
# 4    6  0  0  44   0
# 4S   8  0  0   3   2
# Confusion Matrix for Fold 2 with INSS.Stages:
#      1  2  3   4  4S
# 1   27  0  0   5   0
# 2    0  0  0   1   0
# 3    0  0  0   3   0
# 4    2  0  0  48   0
# 4S   8  0  0   4   1
# Mean Accuracy: 0.7617171717171717
# Mean Precision: 0.7617171717171717
# Mean Recall: 0.7617171717171717
# Mean F1-score: 0.7617171717171717
# Mean ROC-AUC: 0.9362961730095568
# Mean PR-AUC: 0.8007101157985114

# %% [markdown]
# #### SVM (RADIAL) HYPERPARAMETER TUNING FOR SELECTED FEATURES

# %%
#Import necessary libraries
import numpy as np
import pandas as pd
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, roc_curve, auc, precision_recall_curve, average_precision_score
import optuna #hyperparameter optimizer
import matplotlib.pyplot as plt

# %%
#import the train-test split library
from sklearn.model_selection import train_test_split
#X_subset_inss, y_inss


#Split the data (20% for test, because we have small dataset)
X_train_inss, X_test_inss, y_train_inss, y_test_inss = train_test_split(X_sub_inss, y_inss_encode, test_size=0.2, random_state=1)

#Check the dimensions of the data

# %%
########FOR SUPPORT VECTOR MACHINE-HYPER PARAMETER TUNING (we use optuna) ########################

# Define the objective function for optuna
def objective(trial):
    
    C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4 
    gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
    
    svm = SVC(C=C, gamma=gamma, random_state=42, probability=True)
    svm.fit(X_train_inss, y_train_inss)
    predictions = svm.predict(X_test_inss)
    
    return accuracy_score(y_test_inss, predictions)

# Run optuna optimization
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=100)

#We then get the best parameters

# Get the best parameters
best_params = study.best_params
print('Best parameters for SVC: ', best_params)
# Out:
# [I 2023-10-20 13:42:46,181] A new study created in memory with name: no-name-72c3f116-6c17-4eeb-80dd-1fe7d1be72fe
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 13:42:46,211] Trial 0 finished with value: 0.7666666666666667 and parameters: {'C': 47.08100369126952, 'gamma': 0.000758135026212995}. Best is trial 0 with value: 0.7666666666666667.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 13:42:46,281] Trial 1 finished with value: 0.5333333333333333 and parameters: {'C': 0.0036437150717062395, 'gamma': 1020.3072545014367}. Best is trial 0 with value: 0.7666666666666667.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 13:42:46,336] Trial 2 finished with value: 0.5333333333333333 and parameters: {'C': 0.05051274836106326, 'gamma': 651.504057654698}. Best is trial 0 with value: 0.7666666666666667.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 13:42:46,354] Trial 3 finished with value: 0.5333333333333333 and parameters: {'C': 0.0001223731476200417, 'gamma': 0.1428320299310405}. Best is trial 0 with value: 0.7666666666666667.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 13:42:46,401] Trial 4 finished with value: 0.5333333333333333 and parameters: {'C': 0.012910034298906843, 'gamma': 4.409202822620988}. Best is trial 0 with value: 0.7666666666666667.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 13:42:46,460] Trial 5 finished with value: 0.5333333333333333 and parameters: {'C': 23.624769163808907, 'gamma': 35.74856400206217}. Best is trial 0 with value: 0.7666666666666667.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 13:42:46,517] Trial 6 finished with value: 0.5333333333333333 and parameters: {'C': 0.2521960347627976, 'gamma': 323.1579150545844}. Best is trial 0 with value: 0.7666666666666667.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 13:42:46,565] Trial 7 finished with value: 0.5333333333333333 and parameters: {'C': 0.05424753628183564, 'gamma': 4.052038235703663}. Best is trial 0 with value: 0.7666666666666667.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 13:42:46,584] Trial 8 finished with value: 0.5333333333333333 and parameters: {'C': 0.0207997511675336, 'gamma': 0.000532005670405006}. Best is trial 0 with value: 0.7666666666666667.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 13:42:46,621] Trial 9 finished with value: 0.5333333333333333 and parameters: {'C': 0.0028392472731137573, 'gamma': 6.44116626100338}. Best is trial 0 with value: 0.7666666666666667.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 13:42:46,642] Trial 10 finished with value: 0.7166666666666667 and parameters: {'C': 4651.373583223923, 'gamma': 0.00016202824556005795}. Best is trial 0 with value: 0.7666666666666667.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 13:42:46,664] Trial 11 finished with value: 0.7166666666666667 and parameters: {'C': 2476.7278379220165, 'gamma': 0.00013003035697176581}. Best is trial 0 with value: 0.7666666666666667.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 13:42:46,687] Trial 12 finished with value: 0.7333333333333333 and parameters: {'C': 6492.1850140687075, 'gamma': 0.004466806914902655}. Best is trial 0 with value: 0.7666666666666667.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 13:42:46,718] Trial 13 finished with value: 0.7833333333333333 and parameters: {'C': 85.26056776113641, 'gamma': 0.009251377467164392}. Best is trial 13 with value: 0.7833333333333333.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 13:42:46,755] Trial 14 finished with value: 0.7666666666666667 and parameters: {'C': 13.13752620004104, 'gamma': 0.027239590377592205}. Best is trial 13 with value: 0.7833333333333333.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 13:42:46,778] Trial 15 finished with value: 0.7333333333333333 and parameters: {'C': 105.81656632641719, 'gamma': 0.004425888547736503}. Best is trial 13 with value: 0.7833333333333333.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 13:42:46,816] Trial 16 finished with value: 0.5333333333333333 and parameters: {'C': 2.06284738385136, 'gamma': 0.1530843714011108}. Best is trial 13 with value: 0.7833333333333333.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 13:42:46,839] Trial 17 finished with value: 0.7333333333333333 and parameters: {'C': 309.16875265571167, 'gamma': 0.0019856129401431316}. Best is trial 13 with value: 0.7833333333333333.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 13:42:46,873] Trial 18 finished with value: 0.7666666666666667 and parameters: {'C': 2.2589871706411, 'gamma': 0.02302916051601149}. Best is trial 13 with value: 0.7833333333333333.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 13:42:46,894] Trial 19 finished with value: 0.75 and parameters: {'C': 239.0363079997093, 'gamma': 0.0008621654987324422}. Best is trial 13 with value: 0.7833333333333333.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 13:42:46,951] Trial 20 finished with value: 0.5333333333333333 and parameters: {'C': 12.440223412964809, 'gamma': 6487.452778383126}. Best is trial 13 with value: 0.7833333333333333.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 13:42:46,986] Trial 21 finished with value: 0.7666666666666667 and parameters: {'C': 43.561449057492794, 'gamma': 0.019231110761678404}. Best is trial 13 with value: 0.7833333333333333.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 13:42:47,024] Trial 22 finished with value: 0.7666666666666667 and parameters: {'C': 7.15915291648899, 'gamma': 0.0286430445751644}. Best is trial 13 with value: 0.7833333333333333.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 13:42:47,072] Trial 23 finished with value: 0.5333333333333333 and parameters: {'C': 563.1570167202146, 'gamma': 0.1788575583412912}. Best is trial 13 with value: 0.7833333333333333.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 13:42:47,105] Trial 24 finished with value: 0.7833333333333333 and parameters: {'C': 66.50678418046036, 'gamma': 0.009069972553328372}. Best is trial 13 with value: 0.7833333333333333.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 13:42:47,128] Trial 25 finished with value: 0.7333333333333333 and parameters: {'C': 54.07172903191141, 'gamma': 0.0031494908245173997}. Best is trial 13 with value: 0.7833333333333333.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 13:42:47,153] Trial 26 finished with value: 0.7333333333333333 and parameters: {'C': 975.939169305949, 'gamma': 0.00044811109262226}. Best is trial 13 with value: 0.7833333333333333.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 13:42:47,182] Trial 27 finished with value: 0.75 and parameters: {'C': 105.92243723960623, 'gamma': 0.001095560309334465}. Best is trial 13 with value: 0.7833333333333333.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 13:42:47,213] Trial 28 finished with value: 0.7833333333333333 and parameters: {'C': 5.975779140291391, 'gamma': 0.008327405472203085}. Best is trial 13 with value: 0.7833333333333333.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 13:42:47,256] Trial 29 finished with value: 0.5333333333333333 and parameters: {'C': 5.810344678346542, 'gamma': 0.6596921785358595}. Best is trial 13 with value: 0.7833333333333333.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 13:42:47,281] Trial 30 finished with value: 0.75 and parameters: {'C': 1.049679946283383, 'gamma': 0.0047248696209970294}. Best is trial 13 with value: 0.7833333333333333.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 13:42:47,315] Trial 31 finished with value: 0.7833333333333333 and parameters: {'C': 33.74318664114914, 'gamma': 0.009465924951959434}. Best is trial 13 with value: 0.7833333333333333.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 13:42:47,349] Trial 32 finished with value: 0.7833333333333333 and parameters: {'C': 46.02407946604555, 'gamma': 0.008886550944580048}. Best is trial 13 with value: 0.7833333333333333.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 13:42:47,391] Trial 33 finished with value: 0.75 and parameters: {'C': 229.73116114987891, 'gamma': 0.05234590067553215}. Best is trial 13 with value: 0.7833333333333333.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 13:42:47,426] Trial 34 finished with value: 0.7833333333333333 and parameters: {'C': 5.723880187283821, 'gamma': 0.010134507823976631}. Best is trial 13 with value: 0.7833333333333333.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 13:42:47,470] Trial 35 finished with value: 0.65 and parameters: {'C': 1190.1718751359308, 'gamma': 0.07100415716532507}. Best is trial 13 with value: 0.7833333333333333.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 13:42:47,498] Trial 36 finished with value: 0.7666666666666667 and parameters: {'C': 24.972496689643627, 'gamma': 0.0015109381529436327}. Best is trial 13 with value: 0.7833333333333333.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 13:42:47,534] Trial 37 finished with value: 0.7833333333333333 and parameters: {'C': 96.51860735876178, 'gamma': 0.009125699498258557}. Best is trial 13 with value: 0.7833333333333333.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 13:42:47,579] Trial 38 finished with value: 0.5333333333333333 and parameters: {'C': 0.3959290447810595, 'gamma': 0.07333041972159732}. Best is trial 13 with value: 0.7833333333333333.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 13:42:47,624] Trial 39 finished with value: 0.5333333333333333 and parameters: {'C': 21.538750135704987, 'gamma': 0.318362921375172}. Best is trial 13 with value: 0.7833333333333333.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 13:42:47,649] Trial 40 finished with value: 0.7333333333333333 and parameters: {'C': 405.1588783667399, 'gamma': 0.0003780613661928758}. Best is trial 13 with value: 0.7833333333333333.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 13:42:47,684] Trial 41 finished with value: 0.7833333333333333 and parameters: {'C': 55.77764492181306, 'gamma': 0.013943258804089005}. Best is trial 13 with value: 0.7833333333333333.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 13:42:47,717] Trial 42 finished with value: 0.75 and parameters: {'C': 24.93774436044205, 'gamma': 0.006752346721769923}. Best is trial 13 with value: 0.7833333333333333.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 13:42:47,745] Trial 43 finished with value: 0.7333333333333333 and parameters: {'C': 146.72569072050212, 'gamma': 0.0021837251548146616}. Best is trial 13 with value: 0.7833333333333333.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 13:42:47,788] Trial 44 finished with value: 0.75 and parameters: {'C': 44.19396902288179, 'gamma': 0.05370855477395337}. Best is trial 13 with value: 0.7833333333333333.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 13:42:47,820] Trial 45 finished with value: 0.8 and parameters: {'C': 4.217350224832889, 'gamma': 0.00695545179780025}. Best is trial 45 with value: 0.8.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 13:42:47,843] Trial 46 finished with value: 0.7333333333333333 and parameters: {'C': 2.924314186434737, 'gamma': 0.0025124581592474667}. Best is trial 45 with value: 0.8.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 13:42:47,869] Trial 47 finished with value: 0.7666666666666667 and parameters: {'C': 9.431660410862467, 'gamma': 0.0008684214587592293}. Best is trial 45 with value: 0.8.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 13:42:47,893] Trial 48 finished with value: 0.7666666666666667 and parameters: {'C': 4.675141484973111, 'gamma': 0.00027469845351103654}. Best is trial 45 with value: 0.8.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 13:42:47,921] Trial 49 finished with value: 0.7666666666666667 and parameters: {'C': 0.7666582242724866, 'gamma': 0.005767516762966944}. Best is trial 45 with value: 0.8.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 13:42:47,959] Trial 50 finished with value: 0.7833333333333333 and parameters: {'C': 16.622332122236838, 'gamma': 0.017695537668086476}. Best is trial 45 with value: 0.8.
# ...
# [I 2023-10-20 13:42:49,048] Trial 82 finished with value: 0.7333333333333333 and parameters: {'C': 114.604699209019, 'gamma': 0.0035903386432214}. Best is trial 45 with value: 0.8.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 13:42:49,083] Trial 83 finished with value: 0.7833333333333333 and parameters: {'C': 15.905072257717729, 'gamma': 0.014100423543725338}. Best is trial 45 with value: 0.8.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 13:42:49,105] Trial 84 finished with value: 0.7333333333333333 and parameters: {'C': 64.19379245682174, 'gamma': 0.0016202501799330686}. Best is trial 45 with value: 0.8.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 13:42:49,143] Trial 85 finished with value: 0.7833333333333333 and parameters: {'C': 254.8392886073625, 'gamma': 0.033838100264693055}. Best is trial 45 with value: 0.8.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 13:42:49,174] Trial 86 finished with value: 0.7666666666666667 and parameters: {'C': 44.17089470397976, 'gamma': 0.008043951334351136}. Best is trial 45 with value: 0.8.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 13:42:49,200] Trial 87 finished with value: 0.75 and parameters: {'C': 19.930700809077834, 'gamma': 0.0028945725605765567}. Best is trial 45 with value: 0.8.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 13:42:49,239] Trial 88 finished with value: 0.7666666666666667 and parameters: {'C': 93.04866468578766, 'gamma': 0.018447201685768296}. Best is trial 45 with value: 0.8.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 13:42:49,259] Trial 89 finished with value: 0.75 and parameters: {'C': 5.167667653940769, 'gamma': 0.0006178965322838533}. Best is trial 45 with value: 0.8.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 13:42:49,287] Trial 90 finished with value: 0.75 and parameters: {'C': 144.45248615310982, 'gamma': 0.006703463063703733}. Best is trial 45 with value: 0.8.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 13:42:49,317] Trial 91 finished with value: 0.7333333333333333 and parameters: {'C': 49.84780033934746, 'gamma': 0.0042975594077943}. Best is trial 45 with value: 0.8.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 13:42:49,352] Trial 92 finished with value: 0.7833333333333333 and parameters: {'C': 9.546891469088655, 'gamma': 0.014131772340872482}. Best is trial 45 with value: 0.8.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 13:42:49,381] Trial 93 finished with value: 0.7833333333333333 and parameters: {'C': 30.41399186735644, 'gamma': 0.009365822547024791}. Best is trial 45 with value: 0.8.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 13:42:49,419] Trial 94 finished with value: 0.75 and parameters: {'C': 61.97853671513345, 'gamma': 0.022140950541313997}. Best is trial 45 with value: 0.8.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 13:42:49,442] Trial 95 finished with value: 0.75 and parameters: {'C': 21.172499483049005, 'gamma': 0.0026140005801067105}. Best is trial 45 with value: 0.8.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 13:42:49,478] Trial 96 finished with value: 0.7833333333333333 and parameters: {'C': 11.602460242665602, 'gamma': 0.011339886092463027}. Best is trial 45 with value: 0.8.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 13:42:49,505] Trial 97 finished with value: 0.7833333333333333 and parameters: {'C': 3.124023939514435, 'gamma': 0.005455139897220249}. Best is trial 45 with value: 0.8.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 13:42:49,550] Trial 98 finished with value: 0.7666666666666667 and parameters: {'C': 84.66311607962118, 'gamma': 0.04029323825155322}. Best is trial 45 with value: 0.8.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\801237807.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 13:42:49,593] Trial 99 finished with value: 0.7666666666666667 and parameters: {'C': 5.726035380952201, 'gamma': 0.026926756362891945}. Best is trial 45 with value: 0.8.
# Best parameters for SVC:  {'C': 4.217350224832889, 'gamma': 0.00695545179780025}

# %% [markdown]
# #### SVM (RADIAL) CROSS VALIDATION FOR SELECTED FEATURES

# %%
from sklearn.svm import SVC
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score, roc_curve, roc_auc_score, precision_recall_curve, average_precision_score,confusion_matrix
from sklearn.model_selection import StratifiedKFold
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Create a SVM classifier
# Specify hyperparameters
# C_value = 4.058369947278413
# gamma_value = 0.007603796707383056

# Create the SVC with specified hyperparameters
clf = SVC(**best_params, random_state=42, probability=True)

# Define the number of folds for cross-validation
n_splits = 3

# Initialize lists to store metrics for each fold
accuracies = []
precisions = []
recalls = []
f1_scores = []
roc_aucs = []
pr_aucs = []

# Initialize variables for mean ROC-AUC and PR-AUC
mean_roc_auc = 0
mean_pr_auc = 0

# Initialize lists to store ROC and PR curves for each fold
roc_curves = []

# Initialize lists to store recall and precision values for each fold
recall_values = []
precision_values = []

# Initialize the list to store confusion matrices for each fold
confusion_matrices = []

# Create a StratifiedKFold object for cross-validation
skf = StratifiedKFold(n_splits=n_splits)

for train_index, test_index in skf.split(X_sub_inss.values, y_inss_encode):
    X_train, X_test = X_sub_inss.iloc[train_index], X_sub_inss.iloc[test_index]
    y_train, y_test = y_inss_encode[train_index], y_inss_encode[test_index]

    # Train the Random Forest classifier
    clf.fit(X_train, y_train)

    # Make predictions on the test set
    y_pred_probs = clf.predict_proba(X_test)
    y_pred = np.argmax(y_pred_probs, axis=1)

    # Calculate accuracy, precision, recall, and F1-score
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred, average='micro')
    recall = recall_score(y_test, y_pred, average='micro')
    f1 = f1_score(y_test, y_pred, average='micro')

    # Store the metrics for this fold
    accuracies.append(accuracy)
    precisions.append(precision)
    recalls.append(recall)
    f1_scores.append(f1)

    # Calculate ROC-AUC for this fold
    y_true_binary = np.zeros_like(y_pred_probs)
    y_true_binary[np.arange(y_pred_probs.shape[0]), y_test] = 1
    fpr, tpr, _ = roc_curve(y_true_binary.ravel(), y_pred_probs.ravel())
    roc_auc = roc_auc_score(y_true_binary.ravel(), y_pred_probs.ravel())
    roc_aucs.append(roc_auc)
    roc_curves.append((fpr, tpr))

    # Calculate and append the confusion matrix for this fold
    conf_matrix = confusion_matrix(y_test, y_pred)
    confusion_matrices.append(conf_matrix)


    # Calculate Precision-Recall values for this fold
    precision_fold, recall_fold, _ = precision_recall_curve(y_true_binary.ravel(), y_pred_probs.ravel())
    recall_values.append(recall_fold)
    precision_values.append(precision_fold)

    # Calculate PR-AUC for this fold
    pr_auc = average_precision_score(y_true_binary.ravel(), y_pred_probs.ravel())
    pr_aucs.append(pr_auc)

    # Update mean ROC-AUC and PR-AUC
    mean_roc_auc += roc_auc
    mean_pr_auc += pr_auc

# Calculate mean ROC-AUC and PR-AUC across folds
mean_roc_auc /= n_splits
mean_pr_auc /= n_splits

# Obtain unique class labels from y_test_inss
class_labels = ['1', '2', '3', '4', '4S']

# Print the confusion matrices for each fold
for i, conf_matrix in enumerate(confusion_matrices):
    confusion_matrix_df = pd.DataFrame(conf_matrix, index=class_labels, columns=class_labels)
    print(f"Confusion Matrix for Fold {i} with INSS.Stages:")
    print(confusion_matrix_df)

# Print the mean metrics across folds
print("Mean Accuracy:", np.mean(accuracies))
print("Mean Precision:", np.mean(precisions))
print("Mean Recall:", np.mean(recalls))
print("Mean F1-score:", np.mean(f1_scores))
print("Mean ROC-AUC:", mean_roc_auc)
print("Mean PR-AUC:", mean_pr_auc)

# Plot the ROC curve for each fold and the mean ROC-AUC
plt.figure(figsize=(8, 6))
for i, (fpr, tpr) in enumerate(roc_curves):
    roc_auc = roc_aucs[i]
    plt.plot(fpr, tpr, label=f'Fold {i} (AUC = {roc_auc:.2f})')

plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Micro-Averaged ROC Curve (5-Fold Cross-Validation)')
plt.legend(loc='best')
plt.grid()
plt.show()

# Plot the Precision-Recall curves for each fold
plt.figure(figsize=(8, 6))
for i, (recall, precision) in enumerate(zip(recall_values, precision_values)):
    pr_auc = pr_aucs[i]
    plt.plot(recall, precision, label=f'Fold {i} (AUC = {pr_auc:.2f})')

plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Micro-Averaged Precision-Recall Curves (5-Fold Cross-Validation)')
plt.legend(loc='best')
plt.grid()
plt.show()
# Out:
# Confusion Matrix for Fold 0 with INSS.Stages:
#      1  2  3   4  4S
# 1   29  0  0   3   0
# 2    0  0  0   1   0
# 3    0  0  0   3   0
# 4    5  0  0  45   1
# 4S   6  0  0   1   6
# Confusion Matrix for Fold 1 with INSS.Stages:
#      1  2  3   4  4S
# 1   26  0  0   5   1
# 2    0  0  0   1   0
# 3    0  0  0   3   0
# 4    5  0  0  45   0
# 4S   4  0  0   2   7
# Confusion Matrix for Fold 2 with INSS.Stages:
#      1  2  3   4  4S
# 1   28  0  0   3   1
# 2    0  0  0   1   0
# 3    0  0  0   3   0
# 4    3  0  0  47   0
# 4S   4  0  0   3   6
# Mean Accuracy: 0.8020202020202021
# Mean Precision: 0.8020202020202021
# Mean Recall: 0.8020202020202021
# Mean F1-score: 0.8020202020202021
# Mean ROC-AUC: 0.9444215930347243
# Mean PR-AUC: 0.8363331142503042

# %% [markdown]
# #### LOGISTIC REGRESSION HYPERPARAMETER TUNING FOR SELECTED FEATURES

# %%
##############FOR LOGISTIC REGRESSION-HYPER PARAMETER TUNING #########################
from sklearn.linear_model import LogisticRegression
# Set the parameters for random search (for logistic regression)
param_grid = {
    'C': np.logspace(-4, 4, 20),#this search is really large space
    'penalty': ['l1'], #l1 loss
    'solver': ['liblinear']
}

# Initialize a LogisticRegression (define the Logistic regression classifier)
lr = LogisticRegression(random_state=42)

# Initialize Grid_SearchCV (define the random search algorithm#this time we want to use Random serach because we dont want to search the all the combinations)
grid_search = GridSearchCV(estimator=lr, param_grid=param_grid, cv=5)

# Fit Grid_SearchCV
grid_search.fit(X_sub_inss, y_inss)

#after that we  obtain the best parameters from the random search

# Get the best parameters
best_params = grid_search.best_params_
print('Best parameters for LogisticRegression: ', best_params)
# Out:
# Best parameters for LogisticRegression:  {'C': 0.23357214690901212, 'penalty': 'l1', 'solver': 'liblinear'}

# %% [markdown]
# #### LOGISTIC REGRESSION CROSS VALIDATION FOR SELECTED FEATURES

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score, roc_curve, roc_auc_score, precision_recall_curve, average_precision_score,confusion_matrix
from sklearn.model_selection import StratifiedKFold
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Create the LogisticRegression with specified hyperparameters
clf = LogisticRegression(**best_params, random_state=42)

# Define the number of folds for cross-validation
n_splits = 3

# Initialize lists to store metrics for each fold
accuracies = []
precisions = []
recalls = []
f1_scores = []
roc_aucs = []
pr_aucs = []

# Initialize variables for mean ROC-AUC and PR-AUC
mean_roc_auc = 0
mean_pr_auc = 0

# Initialize lists to store ROC and PR curves for each fold
roc_curves = []

# Initialize lists to store recall and precision values for each fold
recall_values = []
precision_values = []

# Initialize the list to store confusion matrices for each fold
confusion_matrices = []

# Create a StratifiedKFold object for cross-validation
skf = StratifiedKFold(n_splits=n_splits)

for train_index, test_index in skf.split(X_sub_inss.values, y_inss_encode):
    X_train, X_test = X_sub_inss.iloc[train_index], X_sub_inss.iloc[test_index]
    y_train, y_test = y_inss_encode[train_index], y_inss_encode[test_index]

    # Train the Random Forest classifier
    clf.fit(X_train, y_train)

    # Make predictions on the test set
    y_pred_probs = clf.predict_proba(X_test)
    y_pred = np.argmax(y_pred_probs, axis=1)

    # Calculate accuracy, precision, recall, and F1-score
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred, average='micro')
    recall = recall_score(y_test, y_pred, average='micro')
    f1 = f1_score(y_test, y_pred, average='micro')

    # Store the metrics for this fold
    accuracies.append(accuracy)
    precisions.append(precision)
    recalls.append(recall)
    f1_scores.append(f1)

    # Calculate ROC-AUC for this fold
    y_true_binary = np.zeros_like(y_pred_probs)
    y_true_binary[np.arange(y_pred_probs.shape[0]), y_test] = 1
    fpr, tpr, _ = roc_curve(y_true_binary.ravel(), y_pred_probs.ravel())
    roc_auc = roc_auc_score(y_true_binary.ravel(), y_pred_probs.ravel())
    roc_aucs.append(roc_auc)
    roc_curves.append((fpr, tpr))

    # Calculate and append the confusion matrix for this fold
    conf_matrix = confusion_matrix(y_test, y_pred)
    confusion_matrices.append(conf_matrix)


    # Calculate Precision-Recall values for this fold
    precision_fold, recall_fold, _ = precision_recall_curve(y_true_binary.ravel(), y_pred_probs.ravel())
    recall_values.append(recall_fold)
    precision_values.append(precision_fold)

    # Calculate PR-AUC for this fold
    pr_auc = average_precision_score(y_true_binary.ravel(), y_pred_probs.ravel())
    pr_aucs.append(pr_auc)

    # Update mean ROC-AUC and PR-AUC
    mean_roc_auc += roc_auc
    mean_pr_auc += pr_auc

# Calculate mean ROC-AUC and PR-AUC across folds
mean_roc_auc /= n_splits
mean_pr_auc /= n_splits

# Obtain unique class labels from y_test_inss
class_labels = ['1', '2', '3', '4', '4S']

# Print the confusion matrices for each fold
for i, conf_matrix in enumerate(confusion_matrices):
    confusion_matrix_df = pd.DataFrame(conf_matrix, index=class_labels, columns=class_labels)
    print(f"Confusion Matrix for Fold {i} with INSS.Stages:")
    print(confusion_matrix_df)

# Print the mean metrics across folds
print("Mean Accuracy:", np.mean(accuracies))
print("Mean Precision:", np.mean(precisions))
print("Mean Recall:", np.mean(recalls))
print("Mean F1-score:", np.mean(f1_scores))
print("Mean ROC-AUC:", mean_roc_auc)
print("Mean PR-AUC:", mean_pr_auc)

# Plot the ROC curve for each fold and the mean ROC-AUC
plt.figure(figsize=(8, 6))
for i, (fpr, tpr) in enumerate(roc_curves):
    roc_auc = roc_aucs[i]
    plt.plot(fpr, tpr, label=f'Fold {i} (AUC = {roc_auc:.2f})')

plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Micro-Averaged ROC Curve (5-Fold Cross-Validation)')
plt.legend(loc='best')
plt.grid()
plt.show()

# Plot the Precision-Recall curves for each fold
plt.figure(figsize=(8, 6))
for i, (recall, precision) in enumerate(zip(recall_values, precision_values)):
    pr_auc = pr_aucs[i]
    plt.plot(recall, precision, label=f'Fold {i} (AUC = {pr_auc:.2f})')

plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Micro-Averaged Precision-Recall Curves (5-Fold Cross-Validation)')
plt.legend(loc='best')
plt.grid()
plt.show()
# Out:
# Confusion Matrix for Fold 0 with INSS.Stages:
#      1  2  3   4  4S
# 1   28  0  0   4   0
# 2    0  0  0   1   0
# 3    0  0  0   3   0
# 4    8  0  0  43   0
# 4S   9  0  0   1   3
# Confusion Matrix for Fold 1 with INSS.Stages:
#      1  2  3   4  4S
# 1   27  0  0   5   0
# 2    0  0  0   1   0
# 3    0  0  0   3   0
# 4    7  0  0  43   0
# 4S   7  0  0   2   4
# Confusion Matrix for Fold 2 with INSS.Stages:
#      1  2  3   4  4S
# 1   27  0  0   4   1
# 2    1  0  0   0   0
# 3    0  0  0   3   0
# 4    5  0  0  45   0
# 4S   5  0  0   3   5
# Mean Accuracy: 0.7550841750841751
# Mean Precision: 0.7550841750841751
# Mean Recall: 0.7550841750841751
# Mean F1-score: 0.7550841750841751
# Mean ROC-AUC: 0.9400967205727307
# Mean PR-AUC: 0.8219020877788829

# %% [markdown]
# ### HYPER PARAMETER TUNING AND CROSS VALIDATION FOR ALL FEATURES

# %% [markdown]
# #### For all Features (no selection) for INSS

# %%
X_train=pd.read_csv("X_train.csv", index_col="ID")
y_train=pd.read_csv("y_train.csv", index_col="ID")

X_all_inss=X_train.copy()

from sklearn.preprocessing import LabelEncoder
# #only get one target
y_inss=y_train["INSS.Stage"]

# Initialize the LabelEncoder
label_encoder = LabelEncoder()

# Fit and transform the class labels to numeric values
y_inss_encode = label_encoder.fit_transform(y_inss)

# Now, if you want to get the original labels from the encoded values:
original_labels = label_encoder.inverse_transform(y_inss_encode)

# %% [markdown]
# X_all_inss y_inss_encode

# %% [markdown]
# #### RANDOM FOREST HYPER PARAMETER TUNING FOR ALL FEATURES

# %%
#Import necessary libraries
from sklearn.model_selection import  GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, roc_curve, auc, precision_recall_curve, average_precision_score

##############FOR RANDOM FOREST-HYPER PARAMETER TUNING#########################

# Set the parameters for grid search (for Random Forest) #we can give choices inside in list as much as we want
param_grid = {
    'n_estimators': [100, 200, 300], 
    'max_depth': [3, 5, 7],
    'min_samples_split': [2, 5, 10]#choices 2,5 and 10
}

# Initialize a RandomForestClassifier (define the Random Forest classifier)
rf = RandomForestClassifier(random_state=42)

# Initialize GridSearchCV (define the grid search algorithm)
grid_search = GridSearchCV(estimator=rf, param_grid=param_grid, cv=5) #here in param_grid ,we provide the param_grid that we set above

# Fit GridSearchCV
grid_search.fit(X_all_inss, y_inss_encode)
#during grid search for train set, every possible combinations of the parameter choices that we set above will be tested.
#And for ever single parameter combination, it will run cross_validation for 5 folds

#after that we obtain the best parameters from the grid search

# Get the best parameters (for the random forest)
best_params = grid_search.best_params_
print('Best parameters for RandomForestClassifier: ', best_params)
# Out:
# Best parameters for RandomForestClassifier:  {'max_depth': 7, 'min_samples_split': 5, 'n_estimators': 100}

# %% [markdown]
# #### RANDOM FOREST CROSS-VALIDATION TUNING FOR ALL FEATURES

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score, roc_curve, roc_auc_score, precision_recall_curve, average_precision_score,confusion_matrix
from sklearn.model_selection import StratifiedKFold
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Create a Random Forest classifier
clf = RandomForestClassifier(**best_params, random_state=42)

# Define the number of folds for cross-validation
n_splits = 3

# Initialize lists to store metrics for each fold
accuracies = []
precisions = []
recalls = []
f1_scores = []
roc_aucs = []
pr_aucs = []

# Initialize variables for mean ROC-AUC and PR-AUC
mean_roc_auc = 0
mean_pr_auc = 0

# Initialize lists to store ROC and PR curves for each fold
roc_curves = []

# Initialize lists to store recall and precision values for each fold
recall_values = []
precision_values = []

# Initialize the list to store confusion matrices for each fold
confusion_matrices = []

# Create a StratifiedKFold object for cross-validation
skf = StratifiedKFold(n_splits=n_splits)

for train_index, test_index in skf.split(X_all_inss.values, y_inss_encode):
    X_train, X_test = X_sub_inss.iloc[train_index], X_sub_inss.iloc[test_index]
    y_train, y_test = y_inss_encode[train_index], y_inss_encode[test_index]

    # Train the Random Forest classifier
    clf.fit(X_train, y_train)

    # Make predictions on the test set
    y_pred_probs = clf.predict_proba(X_test)
    y_pred = np.argmax(y_pred_probs, axis=1)

    # Calculate accuracy, precision, recall, and F1-score
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred, average='micro')
    recall = recall_score(y_test, y_pred, average='micro')
    f1 = f1_score(y_test, y_pred, average='micro')

    # Store the metrics for this fold
    accuracies.append(accuracy)
    precisions.append(precision)
    recalls.append(recall)
    f1_scores.append(f1)

    # Calculate ROC-AUC for this fold
    y_true_binary = np.zeros_like(y_pred_probs)
    y_true_binary[np.arange(y_pred_probs.shape[0]), y_test] = 1
    fpr, tpr, _ = roc_curve(y_true_binary.ravel(), y_pred_probs.ravel())
    roc_auc = roc_auc_score(y_true_binary.ravel(), y_pred_probs.ravel())
    roc_aucs.append(roc_auc)
    roc_curves.append((fpr, tpr))

    # Calculate and append the confusion matrix for this fold
    conf_matrix = confusion_matrix(y_test, y_pred)
    confusion_matrices.append(conf_matrix)


    # Calculate Precision-Recall values for this fold
    precision_fold, recall_fold, _ = precision_recall_curve(y_true_binary.ravel(), y_pred_probs.ravel())
    recall_values.append(recall_fold)
    precision_values.append(precision_fold)

    # Calculate PR-AUC for this fold
    pr_auc = average_precision_score(y_true_binary.ravel(), y_pred_probs.ravel())
    pr_aucs.append(pr_auc)

    # Update mean ROC-AUC and PR-AUC
    mean_roc_auc += roc_auc
    mean_pr_auc += pr_auc

# Calculate mean ROC-AUC and PR-AUC across folds
mean_roc_auc /= n_splits
mean_pr_auc /= n_splits

# Obtain unique class labels from y_test_inss
class_labels = ['1', '2', '3', '4', '4S']

# Print the confusion matrices for each fold
for i, conf_matrix in enumerate(confusion_matrices):
    confusion_matrix_df = pd.DataFrame(conf_matrix, index=class_labels, columns=class_labels)
    print(f"Confusion Matrix for Fold {i} with INSS.Stages:")
    print(confusion_matrix_df)

# Print the mean metrics across folds
print("Mean Accuracy:", np.mean(accuracies))
print("Mean Precision:", np.mean(precisions))
print("Mean Recall:", np.mean(recalls))
print("Mean F1-score:", np.mean(f1_scores))
print("Mean ROC-AUC:", mean_roc_auc)
print("Mean PR-AUC:", mean_pr_auc)

# Plot the ROC curve for each fold and the mean ROC-AUC
plt.figure(figsize=(8, 6))
for i, (fpr, tpr) in enumerate(roc_curves):
    roc_auc = roc_aucs[i]
    plt.plot(fpr, tpr, label=f'Fold {i} (AUC = {roc_auc:.2f})')

plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Micro-Averaged ROC Curve (5-Fold Cross-Validation)')
plt.legend(loc='best')
plt.grid()
plt.show()

# Plot the Precision-Recall curves for each fold
plt.figure(figsize=(8, 6))
for i, (recall, precision) in enumerate(zip(recall_values, precision_values)):
    pr_auc = pr_aucs[i]
    plt.plot(recall, precision, label=f'Fold {i} (AUC = {pr_auc:.2f})')

plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Micro-Averaged Precision-Recall Curves (5-Fold Cross-Validation)')
plt.legend(loc='best')
plt.grid()
plt.show()
# Out:
# Confusion Matrix for Fold 0 with INSS.Stages:
#      1  2  3   4  4S
# 1   30  0  0   2   0
# 2    0  0  0   1   0
# 3    0  0  0   3   0
# 4    5  0  0  46   0
# 4S   8  0  0   5   0
# Confusion Matrix for Fold 1 with INSS.Stages:
#      1  2  3   4  4S
# 1   26  0  0   4   2
# 2    0  0  0   1   0
# 3    0  0  0   3   0
# 4    6  0  0  44   0
# 4S   8  0  0   3   2
# Confusion Matrix for Fold 2 with INSS.Stages:
#      1  2  3   4  4S
# 1   27  0  0   5   0
# 2    0  0  0   1   0
# 3    0  0  0   3   0
# 4    3  0  0  47   0
# 4S   6  0  0   5   2
# Mean Accuracy: 0.7516498316498317
# Mean Precision: 0.7516498316498317
# Mean Recall: 0.7516498316498317
# Mean F1-score: 0.7516498316498317
# Mean ROC-AUC: 0.9347674506002789
# Mean PR-AUC: 0.7933085870595344

# %% [markdown]
# #### SVM HYPER PARAMETER TUNING FOR ALL FEATURES

# %% [markdown]
# X_all_inss y_inss_encode

# %%
#import the train-test split library
from sklearn.model_selection import train_test_split
#X_subset_inss, y_inss


#Split the data (20% for test, because we have small dataset)
X_train_all_inss, X_test_all_inss, y_train_inss, y_test_inss = train_test_split(X_all_inss, y_inss_encode, test_size=0.2, random_state=1)

#Check the dimensions of the data

# %%
import optuna
########FOR SUPPORT VECTOR MACHINE-HYPER PARAMETER TUNING (we use optuna) ########################

# Define the objective function for optuna
def objective(trial):
    
    C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4 
    gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
    
    svm = SVC(C=C, gamma=gamma, random_state=42, probability=True)
    svm.fit(X_train_all_inss, y_train_inss)
    predictions = svm.predict(X_test_all_inss)
    
    return accuracy_score(y_test_inss, predictions)

# Run optuna optimization
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=100)

#We then get the best parameters

# Get the best parameters
best_params = study.best_params
print('Best parameters for SVC: ', best_params)
# Out:
# [I 2023-10-20 15:48:20,805] A new study created in memory with name: no-name-3e7a0eb2-f9cf-4fd3-8b75-9285fd1a91fd
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 15:48:24,878] Trial 0 finished with value: 0.5333333333333333 and parameters: {'C': 0.0038947190216119206, 'gamma': 0.0007104916642178928}. Best is trial 0 with value: 0.5333333333333333.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 15:48:30,246] Trial 1 finished with value: 0.5333333333333333 and parameters: {'C': 507.20725254249413, 'gamma': 0.00023601334407295638}. Best is trial 0 with value: 0.5333333333333333.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 15:48:35,594] Trial 2 finished with value: 0.5333333333333333 and parameters: {'C': 0.8707955487010601, 'gamma': 0.001197243307596636}. Best is trial 0 with value: 0.5333333333333333.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 15:48:40,533] Trial 3 finished with value: 0.5333333333333333 and parameters: {'C': 0.018879498950513583, 'gamma': 136.40236007194417}. Best is trial 0 with value: 0.5333333333333333.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 15:48:45,956] Trial 4 finished with value: 0.5333333333333333 and parameters: {'C': 141.94107747791008, 'gamma': 8585.257435638101}. Best is trial 0 with value: 0.5333333333333333.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 15:48:51,220] Trial 5 finished with value: 0.5333333333333333 and parameters: {'C': 0.027372155772413007, 'gamma': 0.00014822956492679013}. Best is trial 0 with value: 0.5333333333333333.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 15:48:55,034] Trial 6 finished with value: 0.5333333333333333 and parameters: {'C': 0.0012719355724851648, 'gamma': 15.315771152234888}. Best is trial 0 with value: 0.5333333333333333.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 15:49:00,637] Trial 7 finished with value: 0.5333333333333333 and parameters: {'C': 0.6548149440175483, 'gamma': 36.23562346431391}. Best is trial 0 with value: 0.5333333333333333.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 15:49:05,260] Trial 8 finished with value: 0.5333333333333333 and parameters: {'C': 0.007940968332477039, 'gamma': 1.4823413777769825}. Best is trial 0 with value: 0.5333333333333333.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 15:49:10,442] Trial 9 finished with value: 0.5333333333333333 and parameters: {'C': 0.009239276607619399, 'gamma': 2624.99578485043}. Best is trial 0 with value: 0.5333333333333333.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 15:49:13,318] Trial 10 finished with value: 0.5333333333333333 and parameters: {'C': 0.00012669425567462414, 'gamma': 0.01217646224682828}. Best is trial 0 with value: 0.5333333333333333.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 15:49:18,584] Trial 11 finished with value: 0.5333333333333333 and parameters: {'C': 4912.114723879568, 'gamma': 0.016442283857910227}. Best is trial 0 with value: 0.5333333333333333.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 15:49:23,739] Trial 12 finished with value: 0.6833333333333333 and parameters: {'C': 20.804460115526513, 'gamma': 0.00013215515096163472}. Best is trial 12 with value: 0.6833333333333333.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 15:49:28,798] Trial 13 finished with value: 0.5333333333333333 and parameters: {'C': 16.599635874789456, 'gamma': 0.008398397470544241}. Best is trial 12 with value: 0.6833333333333333.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 15:49:33,985] Trial 14 finished with value: 0.5333333333333333 and parameters: {'C': 5.182113248531661, 'gamma': 0.07267700635244846}. Best is trial 12 with value: 0.6833333333333333.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 15:49:39,201] Trial 15 finished with value: 0.5333333333333333 and parameters: {'C': 0.11764018707094918, 'gamma': 0.00014472270296981104}. Best is trial 12 with value: 0.6833333333333333.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 15:49:44,348] Trial 16 finished with value: 0.5333333333333333 and parameters: {'C': 9.85300031106849, 'gamma': 0.0021714996215530455}. Best is trial 12 with value: 0.6833333333333333.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 15:49:49,521] Trial 17 finished with value: 0.5333333333333333 and parameters: {'C': 0.16350657963264373, 'gamma': 0.0009417682514322877}. Best is trial 12 with value: 0.6833333333333333.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 15:49:52,214] Trial 18 finished with value: 0.5333333333333333 and parameters: {'C': 0.000756156379001226, 'gamma': 0.1468974032228338}. Best is trial 12 with value: 0.6833333333333333.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 15:49:57,391] Trial 19 finished with value: 0.5333333333333333 and parameters: {'C': 2.156551906503904, 'gamma': 0.0012205546631897405}. Best is trial 12 with value: 0.6833333333333333.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 15:50:02,884] Trial 20 finished with value: 0.6 and parameters: {'C': 35.00791329610648, 'gamma': 0.00016224124088312967}. Best is trial 12 with value: 0.6833333333333333.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 15:50:08,039] Trial 21 finished with value: 0.7 and parameters: {'C': 36.731601581223195, 'gamma': 0.00011481492773594962}. Best is trial 21 with value: 0.7.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 15:50:13,251] Trial 22 finished with value: 0.6833333333333333 and parameters: {'C': 53.905592100957676, 'gamma': 0.000127635988108736}. Best is trial 21 with value: 0.7.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 15:50:18,361] Trial 23 finished with value: 0.5333333333333333 and parameters: {'C': 80.68086506654736, 'gamma': 0.005960967989262854}. Best is trial 21 with value: 0.7.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 15:50:23,472] Trial 24 finished with value: 0.7 and parameters: {'C': 359.697395863686, 'gamma': 0.00010551350560967109}. Best is trial 21 with value: 0.7.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 15:50:28,658] Trial 25 finished with value: 0.5333333333333333 and parameters: {'C': 255.3220635512334, 'gamma': 0.0005916492023411763}. Best is trial 21 with value: 0.7.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 15:50:33,867] Trial 26 finished with value: 0.5333333333333333 and parameters: {'C': 1151.1870032988966, 'gamma': 0.004478553529418304}. Best is trial 21 with value: 0.7.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 15:50:39,086] Trial 27 finished with value: 0.5333333333333333 and parameters: {'C': 1230.2218825449302, 'gamma': 0.00041073994614109074}. Best is trial 21 with value: 0.7.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 15:50:44,377] Trial 28 finished with value: 0.5333333333333333 and parameters: {'C': 26.52549033882658, 'gamma': 0.001577428309787019}. Best is trial 21 with value: 0.7.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 15:50:49,557] Trial 29 finished with value: 0.5333333333333333 and parameters: {'C': 146.1999547536358, 'gamma': 0.003015435348770435}. Best is trial 21 with value: 0.7.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 15:50:54,739] Trial 30 finished with value: 0.5333333333333333 and parameters: {'C': 5.0422354507706455, 'gamma': 0.0005114129103710789}. Best is trial 21 with value: 0.7.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 15:51:00,119] Trial 31 finished with value: 0.6833333333333333 and parameters: {'C': 63.40843026570789, 'gamma': 0.00012009319394211861}. Best is trial 21 with value: 0.7.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 15:51:05,390] Trial 32 finished with value: 0.7 and parameters: {'C': 36.28931889593976, 'gamma': 0.00011255968610361395}. Best is trial 21 with value: 0.7.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 15:51:10,571] Trial 33 finished with value: 0.5333333333333333 and parameters: {'C': 425.8694196435891, 'gamma': 0.0003609214720291839}. Best is trial 21 with value: 0.7.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 15:51:15,807] Trial 34 finished with value: 0.7 and parameters: {'C': 17.111395360646412, 'gamma': 0.00010279623510145416}. Best is trial 21 with value: 0.7.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 15:51:20,944] Trial 35 finished with value: 0.5333333333333333 and parameters: {'C': 178.72908005787036, 'gamma': 0.0006591695552758105}. Best is trial 21 with value: 0.7.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 15:51:26,139] Trial 36 finished with value: 0.5333333333333333 and parameters: {'C': 9.062822916077673, 'gamma': 0.00029464316557818157}. Best is trial 21 with value: 0.7.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 15:51:31,396] Trial 37 finished with value: 0.5333333333333333 and parameters: {'C': 69.31591988127488, 'gamma': 0.0013886997892527452}. Best is trial 21 with value: 0.7.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 15:51:36,552] Trial 38 finished with value: 0.5333333333333333 and parameters: {'C': 789.7400702673956, 'gamma': 0.00041313706087099943}. Best is trial 21 with value: 0.7.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 15:51:41,910] Trial 39 finished with value: 0.5333333333333333 and parameters: {'C': 368.37000817355636, 'gamma': 0.0025932391006833738}. Best is trial 21 with value: 0.7.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 15:51:47,108] Trial 40 finished with value: 0.7 and parameters: {'C': 1.5179168239315224, 'gamma': 0.00011442887930202243}. Best is trial 21 with value: 0.7.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 15:51:52,248] Trial 41 finished with value: 0.7333333333333333 and parameters: {'C': 1.982645393948521, 'gamma': 0.00010047923578072409}. Best is trial 41 with value: 0.7333333333333333.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 15:51:57,466] Trial 42 finished with value: 0.5333333333333333 and parameters: {'C': 21.65360022350552, 'gamma': 0.00031459418518139655}. Best is trial 41 with value: 0.7333333333333333.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 15:52:02,879] Trial 43 finished with value: 0.5333333333333333 and parameters: {'C': 3.6962586295157966, 'gamma': 0.0007561853015735124}. Best is trial 41 with value: 0.7333333333333333.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 15:52:08,067] Trial 44 finished with value: 0.5333333333333333 and parameters: {'C': 0.7976473631770535, 'gamma': 0.0002752319203284814}. Best is trial 41 with value: 0.7333333333333333.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 15:52:13,183] Trial 45 finished with value: 0.5333333333333333 and parameters: {'C': 94.33065145061816, 'gamma': 0.00023831687485012087}. Best is trial 41 with value: 0.7333333333333333.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 15:52:18,664] Trial 46 finished with value: 0.7 and parameters: {'C': 11.042180147012308, 'gamma': 0.0001024470102980464}. Best is trial 41 with value: 0.7333333333333333.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 15:52:24,370] Trial 47 finished with value: 0.5333333333333333 and parameters: {'C': 34.59031143151824, 'gamma': 0.001102239132631753}. Best is trial 41 with value: 0.7333333333333333.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 15:52:29,676] Trial 48 finished with value: 0.5333333333333333 and parameters: {'C': 159.1707332790098, 'gamma': 0.003952776785622534}. Best is trial 41 with value: 0.7333333333333333.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 15:52:34,963] Trial 49 finished with value: 0.5333333333333333 and parameters: {'C': 2.5987483947499923, 'gamma': 0.01984824305440078}. Best is trial 41 with value: 0.7333333333333333.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 15:52:40,222] Trial 50 finished with value: 0.5333333333333333 and parameters: {'C': 7.689190759563449, 'gamma': 0.0002473453454240337}. Best is trial 41 with value: 0.7333333333333333.
# ...
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 15:55:30,467] Trial 83 finished with value: 0.5333333333333333 and parameters: {'C': 14.861661278985864, 'gamma': 0.0003326399134362938}. Best is trial 41 with value: 0.7333333333333333.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 15:55:35,662] Trial 84 finished with value: 0.5333333333333333 and parameters: {'C': 3.373682938375386, 'gamma': 0.000530758451651087}. Best is trial 41 with value: 0.7333333333333333.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 15:55:40,749] Trial 85 finished with value: 0.6333333333333333 and parameters: {'C': 58.997659741303345, 'gamma': 0.0001549982708914133}. Best is trial 41 with value: 0.7333333333333333.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 15:55:45,940] Trial 86 finished with value: 0.7333333333333333 and parameters: {'C': 6.603850395223629, 'gamma': 0.00010119340200366342}. Best is trial 41 with value: 0.7333333333333333.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 15:55:50,952] Trial 87 finished with value: 0.5333333333333333 and parameters: {'C': 5.377728102795238, 'gamma': 0.0002931526057851296}. Best is trial 41 with value: 0.7333333333333333.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 15:55:56,046] Trial 88 finished with value: 0.5333333333333333 and parameters: {'C': 113.18566589669629, 'gamma': 0.0007721138984427146}. Best is trial 41 with value: 0.7333333333333333.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 15:56:01,135] Trial 89 finished with value: 0.55 and parameters: {'C': 0.8583145274742908, 'gamma': 0.00015290838021896782}. Best is trial 41 with value: 0.7333333333333333.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 15:56:06,387] Trial 90 finished with value: 0.5333333333333333 and parameters: {'C': 9.054716597503488, 'gamma': 0.0004648334505337617}. Best is trial 41 with value: 0.7333333333333333.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 15:56:11,442] Trial 91 finished with value: 0.7 and parameters: {'C': 21.497551111237925, 'gamma': 0.00010319491506068421}. Best is trial 41 with value: 0.7333333333333333.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 15:56:16,565] Trial 92 finished with value: 0.5333333333333333 and parameters: {'C': 7.216002341916467, 'gamma': 0.0002684257626743422}. Best is trial 41 with value: 0.7333333333333333.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 15:56:21,694] Trial 93 finished with value: 0.6 and parameters: {'C': 12.267045692888733, 'gamma': 0.00016264823527109833}. Best is trial 41 with value: 0.7333333333333333.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 15:56:26,791] Trial 94 finished with value: 0.7333333333333333 and parameters: {'C': 2.646953723953932, 'gamma': 0.00010005336937075502}. Best is trial 41 with value: 0.7333333333333333.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 15:56:31,860] Trial 95 finished with value: 0.5333333333333333 and parameters: {'C': 3.7319646157265147, 'gamma': 0.000264844676358136}. Best is trial 41 with value: 0.7333333333333333.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 15:56:37,074] Trial 96 finished with value: 0.6333333333333333 and parameters: {'C': 1.9029696025714347, 'gamma': 0.0001545738763154228}. Best is trial 41 with value: 0.7333333333333333.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 15:56:42,231] Trial 97 finished with value: 0.5333333333333333 and parameters: {'C': 1.2262576705719144, 'gamma': 0.00044877201513242673}. Best is trial 41 with value: 0.7333333333333333.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 15:56:47,387] Trial 98 finished with value: 0.5333333333333333 and parameters: {'C': 2.3820655966740345, 'gamma': 0.00022753774224434404}. Best is trial 41 with value: 0.7333333333333333.
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('C', 1e-4, 1e4) # C value hyperparameter and we are searching a parameter from 1e-4 to 1e4
# C:\Users\isile\AppData\Local\Temp\ipykernel_32072\2696776492.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-4, 1e4) #kernel hyperparameter
# [I 2023-10-20 15:56:52,546] Trial 99 finished with value: 0.7333333333333333 and parameters: {'C': 33.87239721466539, 'gamma': 0.00010011487847464257}. Best is trial 41 with value: 0.7333333333333333.
# Best parameters for SVC:  {'C': 1.982645393948521, 'gamma': 0.00010047923578072409}

# %% [markdown]
# #### SVM CROSS-VALIDATION FOR ALL FEATURES

# %%
from sklearn.svm import SVC
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score, roc_curve, roc_auc_score, precision_recall_curve, average_precision_score,confusion_matrix
from sklearn.model_selection import StratifiedKFold
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Create a SVM classifier
# Specify hyperparameters
# C_value = 1.982645393948521
# gamma_value = 0.00010047923578072409

# Create the SVC with specified hyperparameters
clf = SVC(**best_params, random_state=42, probability=True)

# Define the number of folds for cross-validation
n_splits = 3

# Initialize lists to store metrics for each fold
accuracies = []
precisions = []
recalls = []
f1_scores = []
roc_aucs = []
pr_aucs = []

# Initialize variables for mean ROC-AUC and PR-AUC
mean_roc_auc = 0
mean_pr_auc = 0

# Initialize lists to store ROC and PR curves for each fold
roc_curves = []

# Initialize lists to store recall and precision values for each fold
recall_values = []
precision_values = []

# Initialize the list to store confusion matrices for each fold
confusion_matrices = []

# Create a StratifiedKFold object for cross-validation
skf = StratifiedKFold(n_splits=n_splits)

for train_index, test_index in skf.split(X_sub_inss.values, y_inss_encode):
    X_train, X_test = X_sub_inss.iloc[train_index], X_sub_inss.iloc[test_index]
    y_train, y_test = y_inss_encode[train_index], y_inss_encode[test_index]

    # Train the Random Forest classifier
    clf.fit(X_train, y_train)

    # Make predictions on the test set
    y_pred_probs = clf.predict_proba(X_test)
    y_pred = np.argmax(y_pred_probs, axis=1)

    # Calculate accuracy, precision, recall, and F1-score
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred, average='micro')
    recall = recall_score(y_test, y_pred, average='micro')
    f1 = f1_score(y_test, y_pred, average='micro')

    # Store the metrics for this fold
    accuracies.append(accuracy)
    precisions.append(precision)
    recalls.append(recall)
    f1_scores.append(f1)

    # Calculate ROC-AUC for this fold
    y_true_binary = np.zeros_like(y_pred_probs)
    y_true_binary[np.arange(y_pred_probs.shape[0]), y_test] = 1
    fpr, tpr, _ = roc_curve(y_true_binary.ravel(), y_pred_probs.ravel())
    roc_auc = roc_auc_score(y_true_binary.ravel(), y_pred_probs.ravel())
    roc_aucs.append(roc_auc)
    roc_curves.append((fpr, tpr))

    # Calculate and append the confusion matrix for this fold
    conf_matrix = confusion_matrix(y_test, y_pred)
    confusion_matrices.append(conf_matrix)


    # Calculate Precision-Recall values for this fold
    precision_fold, recall_fold, _ = precision_recall_curve(y_true_binary.ravel(), y_pred_probs.ravel())
    recall_values.append(recall_fold)
    precision_values.append(precision_fold)

    # Calculate PR-AUC for this fold
    pr_auc = average_precision_score(y_true_binary.ravel(), y_pred_probs.ravel())
    pr_aucs.append(pr_auc)

    # Update mean ROC-AUC and PR-AUC
    mean_roc_auc += roc_auc
    mean_pr_auc += pr_auc

# Calculate mean ROC-AUC and PR-AUC across folds
mean_roc_auc /= n_splits
mean_pr_auc /= n_splits

# Obtain unique class labels from y_test_inss
class_labels = ['1', '2', '3', '4', '4S']

# Print the confusion matrices for each fold
for i, conf_matrix in enumerate(confusion_matrices):
    confusion_matrix_df = pd.DataFrame(conf_matrix, index=class_labels, columns=class_labels)
    print(f"Confusion Matrix for Fold {i} with INSS.Stages:")
    print(confusion_matrix_df)

# Print the mean metrics across folds
print("Mean Accuracy:", np.mean(accuracies))
print("Mean Precision:", np.mean(precisions))
print("Mean Recall:", np.mean(recalls))
print("Mean F1-score:", np.mean(f1_scores))
print("Mean ROC-AUC:", mean_roc_auc)
print("Mean PR-AUC:", mean_pr_auc)

# Plot the ROC curve for each fold and the mean ROC-AUC
plt.figure(figsize=(8, 6))
for i, (fpr, tpr) in enumerate(roc_curves):
    roc_auc = roc_aucs[i]
    plt.plot(fpr, tpr, label=f'Fold {i} (AUC = {roc_auc:.2f})')

plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Micro-Averaged ROC Curve (5-Fold Cross-Validation)')
plt.legend(loc='best')
plt.grid()
plt.show()

# Plot the Precision-Recall curves for each fold
plt.figure(figsize=(8, 6))
for i, (recall, precision) in enumerate(zip(recall_values, precision_values)):
    pr_auc = pr_aucs[i]
    plt.plot(recall, precision, label=f'Fold {i} (AUC = {pr_auc:.2f})')

plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Micro-Averaged Precision-Recall Curves (5-Fold Cross-Validation)')
plt.legend(loc='best')
plt.grid()
plt.show()
# Out:
# Confusion Matrix for Fold 0 with INSS.Stages:
#      1  2  3   4  4S
# 1   29  0  0   3   0
# 2    0  0  0   1   0
# 3    0  0  0   3   0
# 4    7  0  0  44   0
# 4S   7  0  0   4   2
# Confusion Matrix for Fold 1 with INSS.Stages:
#      1  2  3   4  4S
# 1   26  0  0   5   1
# 2    0  0  1   0   0
# 3    0  0  0   3   0
# 4    6  0  0  44   0
# 4S   4  0  0   2   7
# Confusion Matrix for Fold 2 with INSS.Stages:
#      1  2  3   4  4S
# 1   26  0  0   5   1
# 2    0  0  0   1   0
# 3    0  0  0   3   0
# 4    3  0  0  47   0
# 4S   6  0  0   4   3
# Mean Accuracy: 0.7651515151515151
# Mean Precision: 0.7651515151515151
# Mean Recall: 0.7651515151515151
# Mean F1-score: 0.7651515151515151
# Mean ROC-AUC: 0.936161781110771
# Mean PR-AUC: 0.8032295511732225

# %% [markdown]
# #### LOGISTIC REGRESSION HYPER PARAMETER TUNING FOR ALL FEATURES

# %%
##############FOR LOGISTIC REGRESSION-HYPER PARAMETER TUNING #########################
from sklearn.linear_model import LogisticRegression
# Set the parameters for random search (for logistic regression)
param_grid = {
    'C': np.logspace(-4, 4, 20),#this search is really large space
    'penalty': ['l1'], #l1 loss
    'solver': ['liblinear']
}

# Initialize a LogisticRegression (define the Logistic regression classifier)
lr = LogisticRegression(random_state=42)

# Initialize Grid_SearchCV (define the random search algorithm#this time we want to use Random serach because we dont want to search the all the combinations)
grid_search = GridSearchCV(estimator=lr, param_grid=param_grid, cv=5)

# Fit Grid_SearchCV
grid_search.fit(X_all_inss, y_inss_encode)

#after that we  obtain the best parameters from the random search

# Get the best parameters
best_params = grid_search.best_params_
print('Best parameters for LogisticRegression: ', best_params)
# Out:
# Best parameters for LogisticRegression:  {'C': 0.23357214690901212, 'penalty': 'l1', 'solver': 'liblinear'}

# %% [markdown]
# #### LOGISTIC REGRESSION CROSS VALIDATION FOR ALL FEATURES

# %% [markdown]
# X_all_inss y_inss_encode

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score, roc_curve, roc_auc_score, precision_recall_curve, average_precision_score,confusion_matrix
from sklearn.model_selection import StratifiedKFold
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Create the LogisticRegression with specified hyperparameters
clf = LogisticRegression(**best_params, random_state=42)

# Define the number of folds for cross-validation
n_splits = 3

# Initialize lists to store metrics for each fold
accuracies = []
precisions = []
recalls = []
f1_scores = []
roc_aucs = []
pr_aucs = []

# Initialize variables for mean ROC-AUC and PR-AUC
mean_roc_auc = 0
mean_pr_auc = 0

# Initialize lists to store ROC and PR curves for each fold
roc_curves = []

# Initialize lists to store recall and precision values for each fold
recall_values = []
precision_values = []

# Initialize the list to store confusion matrices for each fold
confusion_matrices = []

# Create a StratifiedKFold object for cross-validation
skf = StratifiedKFold(n_splits=n_splits)

for train_index, test_index in skf.split(X_all_inss.values, y_inss_encode):
    X_train, X_test = X_sub_inss.iloc[train_index], X_sub_inss.iloc[test_index]
    y_train, y_test = y_inss_encode[train_index], y_inss_encode[test_index]

    # Train the Random Forest classifier
    clf.fit(X_train, y_train)

    # Make predictions on the test set
    y_pred_probs = clf.predict_proba(X_test)
    y_pred = np.argmax(y_pred_probs, axis=1)

    # Calculate accuracy, precision, recall, and F1-score
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred, average='micro')
    recall = recall_score(y_test, y_pred, average='micro')
    f1 = f1_score(y_test, y_pred, average='micro')

    # Store the metrics for this fold
    accuracies.append(accuracy)
    precisions.append(precision)
    recalls.append(recall)
    f1_scores.append(f1)

    # Calculate ROC-AUC for this fold
    y_true_binary = np.zeros_like(y_pred_probs)
    y_true_binary[np.arange(y_pred_probs.shape[0]), y_test] = 1
    fpr, tpr, _ = roc_curve(y_true_binary.ravel(), y_pred_probs.ravel())
    roc_auc = roc_auc_score(y_true_binary.ravel(), y_pred_probs.ravel())
    roc_aucs.append(roc_auc)
    roc_curves.append((fpr, tpr))

    # Calculate and append the confusion matrix for this fold
    conf_matrix = confusion_matrix(y_test, y_pred)
    confusion_matrices.append(conf_matrix)


    # Calculate Precision-Recall values for this fold
    precision_fold, recall_fold, _ = precision_recall_curve(y_true_binary.ravel(), y_pred_probs.ravel())
    recall_values.append(recall_fold)
    precision_values.append(precision_fold)

    # Calculate PR-AUC for this fold
    pr_auc = average_precision_score(y_true_binary.ravel(), y_pred_probs.ravel())
    pr_aucs.append(pr_auc)

    # Update mean ROC-AUC and PR-AUC
    mean_roc_auc += roc_auc
    mean_pr_auc += pr_auc

# Calculate mean ROC-AUC and PR-AUC across folds
mean_roc_auc /= n_splits
mean_pr_auc /= n_splits

# Obtain unique class labels from y_test_inss
class_labels = class_labels = ['1', '2', '3', '4', '4S']

# Print the confusion matrices for each fold
for i, conf_matrix in enumerate(confusion_matrices):
    confusion_matrix_df = pd.DataFrame(conf_matrix, index=class_labels, columns=class_labels)
    print(f"Confusion Matrix for Fold {i} with INSS.Stages:")
    print(confusion_matrix_df)

# Print the mean metrics across folds
print("Mean Accuracy:", np.mean(accuracies))
print("Mean Precision:", np.mean(precisions))
print("Mean Recall:", np.mean(recalls))
print("Mean F1-score:", np.mean(f1_scores))
print("Mean ROC-AUC:", mean_roc_auc)
print("Mean PR-AUC:", mean_pr_auc)

# Plot the ROC curve for each fold and the mean ROC-AUC
plt.figure(figsize=(8, 6))
for i, (fpr, tpr) in enumerate(roc_curves):
    roc_auc = roc_aucs[i]
    plt.plot(fpr, tpr, label=f'Fold {i} (AUC = {roc_auc:.2f})')

plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Micro-Averaged ROC Curve (5-Fold Cross-Validation)')
plt.legend(loc='best')
plt.grid()
plt.show()

# Plot the Precision-Recall curves for each fold
plt.figure(figsize=(8, 6))
for i, (recall, precision) in enumerate(zip(recall_values, precision_values)):
    pr_auc = pr_aucs[i]
    plt.plot(recall, precision, label=f'Fold {i} (AUC = {pr_auc:.2f})')

plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Micro-Averaged Precision-Recall Curves (5-Fold Cross-Validation)')
plt.legend(loc='best')
plt.grid()
plt.show()
# Out:
# Confusion Matrix for Fold 0 with INSS.Stages:
#      1  2  3   4  4S
# 1   28  0  0   4   0
# 2    0  0  0   1   0
# 3    0  0  0   3   0
# 4    8  0  0  43   0
# 4S   9  0  0   1   3
# Confusion Matrix for Fold 1 with INSS.Stages:
#      1  2  3   4  4S
# 1   27  0  0   5   0
# 2    0  0  0   1   0
# 3    0  0  0   3   0
# 4    7  0  0  43   0
# 4S   7  0  0   2   4
# Confusion Matrix for Fold 2 with INSS.Stages:
#      1  2  3   4  4S
# 1   27  0  0   4   1
# 2    1  0  0   0   0
# 3    0  0  0   3   0
# 4    5  0  0  45   0
# 4S   5  0  0   3   5
# Mean Accuracy: 0.7550841750841751
# Mean Precision: 0.7550841750841751
# Mean Recall: 0.7550841750841751
# Mean F1-score: 0.7550841750841751
# Mean ROC-AUC: 0.9400967205727307
# Mean PR-AUC: 0.8219020877788829

# %% [markdown]
# #### EXTRAS

# %% [markdown]
# SINGLE MODEL EVALUATION FOR MULTICLASS CLINICAL ENDPOINT(INSS.STAGE)

# %%
# from sklearn.ensemble import RandomForestClassifier
# from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score, roc_curve, roc_auc_score,average_precision_score
# import numpy as np
# import pandas as pd
# %matplotlib inline


# # Create a Random Forest classifier
# clf = RandomForestClassifier(**best_params, random_state=42)  # You can adjust parameters as needed

# # Train the Random Forest classifier
# clf.fit(X_train_inss, y_train_inss)

# # Make predictions on the test set
# y_pred_probs = clf.predict_proba(X_test_inss)  # Predict probabilities for all classes

# # Calculate accuracy using scikit-learn's accuracy_score
# y_pred = np.argmax(y_pred_probs, axis=1)  # Get the predicted class labels
# accuracy = accuracy_score(y_test_inss, y_pred)
# print("Accuracy:", accuracy)

# # Calculate precision, recall, and F1-score
# precision = precision_score(y_test_inss, y_pred, average='micro')
# recall = recall_score(y_test_inss, y_pred, average='micro')
# f1 = f1_score(y_test_inss, y_pred, average='micro')

# # Print the precision,recall and f1 
# print("Precision:", precision)
# print("Recall:", recall)
# print("F1-score:", f1)

# # Obtain unique class labels from y_test_inss
# class_labels = ['1', '2', '3', '4', '4S']#np.unique(y_test_inss)

# # Combine the predicted probabilities into a single array
# y_combined = np.vstack(y_pred_probs)

# # Create binary true labels, where the positive class is 1 and all other classes are 0
# y_true_binary = np.zeros_like(y_combined)
# y_true_binary[np.arange(y_combined.shape[0]), y_test_inss] = 1

# # Compute micro-averaged ROC curve and AUC
# fpr, tpr, _ = roc_curve(y_true_binary.ravel(), y_combined.ravel())
# micro_roc_auc = roc_auc_score(y_true_binary.ravel(), y_combined.ravel())

# # Calculate PR-AUC for each class
# pr_auc_per_class = average_precision_score(y_true_binary, y_pred_probs, average=None)
# # Calculate micro-averaged PR-AUC
# micro_pr_auc = average_precision_score(y_true_binary, y_pred_probs, average='micro')

# # Print the PR-AUC for each class and the micro-averaged PR-AUC
# for class_label, pr_auc in zip(class_labels, pr_auc_per_class):
#     print(f"PR-AUC for Class {class_label}: {pr_auc:.2f}")

# print(f"Micro-Averaged PR-AUC: {micro_pr_auc:.2f}")

# #Print the micro-averaged ROC AUC
# print("Micro-Averaged ROC AUC:", micro_roc_auc)

# # Calculate and print the confusion matrix
# conf_matrix = confusion_matrix(y_test_inss, y_pred)
# confusion_matrix_df = pd.DataFrame(conf_matrix, index=class_labels, columns=class_labels)
# print("Confusion Matrix with INSS.Stages:")
# print(confusion_matrix_df)


# # Compute micro-averaged ROC and PR
# fpr_micro, tpr_micro, _ = roc_curve(y_true_binary.ravel(), y_pred_probs.ravel())
# precision_micro, recall_micro, _ = precision_recall_curve(y_true_binary.ravel(), y_pred_probs.ravel())

# # Plot the micro-averaged ROC curve
# plt.figure(figsize=(8, 6))
# plt.plot(fpr_micro, tpr_micro, label=f'Micro-Averaged ROC (AUC = {micro_roc_auc:.2f})')
# plt.plot([0, 1], [0, 1], 'k--')
# plt.xlabel('False Positive Rate')
# plt.ylabel('True Positive Rate')
# plt.title('Micro-Averaged ROC Curve')
# plt.legend(loc='best')
# plt.grid()
# plt.show()

# # Plot the micro-averaged PR curve
# plt.figure(figsize=(8, 6))
# plt.plot(recall_micro, precision_micro, label=f'Micro-Averaged PR (AUC = {micro_pr_auc:.2f})')
# plt.xlabel('Recall')
# plt.ylabel('Precision')
# plt.title('Micro-Averaged Precision-Recall Curve')
# plt.legend(loc='best')
# plt.grid()
# plt.show()



#For each subclass
# # Plot the ROC curve
# plt.figure(figsize=(8, 6))
# for i in range(len(class_labels)):
#     fpr, tpr, _ = roc_curve(y_true_binary[:, i], y_pred_probs[:, i])
#     plt.plot(fpr, tpr, label=f'ROC-AUC for INSS.Stages {class_labels[i]}')

# plt.plot([0, 1], [0, 1], 'k--')
# plt.xlabel('False Positive Rate')
# plt.ylabel('True Positive Rate')
# plt.title('ROC Curve')
# plt.legend(loc='best')
# plt.grid()
# plt.show()

# # Plot the PR curve
# plt.figure(figsize=(8, 6))
# for i in range(len(class_labels)):
#     precision, recall, _ = precision_recall_curve(y_true_binary[:, i], y_pred_probs[:, i])
#     plt.plot(recall, precision, label=f'PR-AUC for INSS.Stages {class_labels[i]}')

# plt.xlabel('Recall')
# plt.ylabel('Precision')
# plt.title('Precision-Recall Curve')
# plt.legend(loc='best')
# plt.grid()
# plt.show()
# Out:
# 0.8129970893201472

# %% [markdown]
#     Micro-Averaged Metrics:
#         Micro-averaging gives more weight to larger classes, which can be helpful when you have class imbalance. If some classes are much smaller than others, micro-averaged metrics provide a better overall assessment of the model's performance.
#         It's suitable when you want to evaluate the model's performance as a whole, without considering class sizes.
#
#     Macro-Averaged Metrics:
#         Macro-averaging treats all classes equally and calculates the metric independently for each class. It provides an overall measure of model performance that doesn't give preference to larger classes.
#         It's suitable when you want to assess the model's ability to perform well on each class independently, without being influenced by class imbalance.
#
# Which one to choose depends on the context of your problem and what you consider more important. Here are some considerations to help you decide:
#
#     Use Micro-Averaging When:
#         Class sizes vary significantly.
#         You want an overall assessment of the model's performance across all classes, with more weight given to larger classes.
#         You want to measure how well the model handles rare classes or highly imbalanced datasets.
#
#     Use Macro-Averaging When:
#         You want to evaluate the model's ability to perform well on each class independently, regardless of class sizes.
#         All classes are considered equally important.
#         You want to identify classes where the model's performance may need improvement.

# %%
# unique_class_labels = y_inss.unique()
# print("Class Labels in the Dataset:")
# for label in unique_class_labels:
#     print(label)
# Out:
# Class Labels in the Dataset:
# 4
# 4S
# 1
# 3
# 2
